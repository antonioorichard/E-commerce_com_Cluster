# %% [markdown]
# # README

# %% [markdown]
# Este projeto, seguirar uma metodologia diferente dos demais anteriores a este, será feito baseado em um projeto de outro aluno(a),
# no caso este link(). Por fim, terá no meu respositório dois notebook, o que segue o da minha colega mais uma reflexão quando
# descordar do caminho tomado ou desenvolvido mais subjetivo, não que eu seja voz da razão, sei que aprenderei muito com ela.
# Por último, um notebook final, que será mais enchuto, por ser construído após a aula do professor Meigram!

# %% [markdown]
# # 0.0 imports

# %%
#dataprocess
import pandas as pd
import numpy  as np
import re
import inflection

# Gráficos
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 0.1 Help fucntion

# %% [markdown]
# # 1. Load Dataset

# %%
dff = pd.read_csv('/home/win/Documentos/pa05/data/Ecommerce.csv', encoding='latin1')

# %%
df = dff

# %%
# Analisando os dados 
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country  Unnamed: 8
# 0   29-Nov-16       2.55     17850.0  United Kingdom         NaN
# 1   29-Nov-16       3.39     17850.0  United Kingdom         NaN
# 2   29-Nov-16       2.75     17850.0  United Kingdom         NaN
# 3   29-Nov-16       3.39     17850.0  United Kingdom         NaN
# 4   29-Nov-16       3.39     17850.0  United Kingdom         NaN

# %%
df['Unnamed: 8'].unique()
# Out:
# array([nan])

# %% [markdown]
# * coluna 'Unnamed: 8' deve ser dropada!

# %%
df.drop(columns = 'Unnamed: 8',  inplace = True)

# %% [markdown]
# # 2. Data Description

# %% [markdown]
# **Contexto**
#
# Dados de comércio Eletrônico
#
# **Conteúdo**
#
# Este é um conjunto de dados transnacional que contém todas as transações que ocorrem entre 01/12/2010 e 09/12/2011 para um varejo on-line sem loja com sede no Reino Unido e registrado. A empresa vende principalmente presentes exclusivos de todas as ocasiões. Muitos clientes da empresa são atacadistas.
#
# fonte: https://archive.ics.uci.edu/dataset/502/online+retail+ii

# %% [markdown]
#                             **Attribute Description**
#
# InvoiceNo:    Número da fatura (um número integral de 6 dígitos atribuído exclusivamente a cada transação)
#
# StockCode:    Código do produto (item)
#
# Description:  Product (item) name
#
# Quantity:     As quantidades de cada produto (item) por transação
#
# InvoiceDate:  O dia em que cada transação foi gerada
#
# UnitPrice:    Preço unitário (Preço do produto por unidade)
#
# CustomerID:   Número do cliente (ID exclusivo atribuído a cada cliente)
#
# Country:      Nome do país (O nome do país onde cada cliente reside)
#
# Analysis tasks to be performed:
#
# Use the clustering methodology to segment customers into groups:

# %% [markdown]
# | Nome variável       | Papel     | Tipo | Descrião do produto | Unidades de Ações | Valores perdidos|
# |--------------|-----------|------------|------------|------------|------------|
# | InvoiceNo (em voz) | ID     | Categorial   | um número integral de 6 dígitos atribuído exclusivamente a cada transação. **Se este código começar com a letra 'c', indica um cancelamento**|| No|
# | Cod,o do stock     | ID     | Categorial       |um número integral de 5 dígitos atribuído exclusivamente a cada produto distinto|| No|
# |Description|	Feature|	Categorical|	product name|		|no|
# |Quantity	|Feature|	Integer|	the quantities of each product (item) per transaction|		|no|
# |InvoiceDate	|Feature	|Date|	the day and time when each transaction was generated|		|no|
# |UnitPrice	|Feature	|Continuous	|product price per unit	|sterling|	no|
# |CustomerID|Feature|Categorical|um número integral de 5 dígitos atribuído exclusivamente a cada cliente|	|no|
# |Country|	Feature|	Categorical|	the name of the country where each customer resides|		|no|

# %% [markdown]
# | Item         | Price | # In stock |
# |--------------|:-----:|-----------:|
# | Juicy Apples |  1.99 |        739 |
# | Bananas      |  1.89 |          6 |

# %% [markdown]
# ## 2.1 Rename Columns

# %%
list(df.columns)
# Out:
# ['InvoiceNo',
#  'StockCode',
#  'Description',
#  'Quantity',
#  'InvoiceDate',
#  'UnitPrice',
#  'CustomerID',
#  'Country']

# %%
cols_old = list(df.columns)

snakecase = lambda x : inflection.underscore( x )
cols_new = list(map(snakecase, cols_old))

df.columns = cols_new

# %% [markdown]
# ## 2.2 Data Dimensions

# %%
print('Number of Rows: {}'.format( df.shape[0]))
print( 'Number of Cols: {}'.format( df.shape[1] ) )
# Out:
# Number of Rows: 541909
# Number of Cols: 8

# %% [markdown]
# ## 2.3 Data Types

# %%
df.dtypes
# Out:
# invoice_no       object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# customer_id     float64
# country          object
# dtype: object

# %%
df['invoice_no'].unique()
# Out:
# array(['536365', '536366', '536367', ..., '581585', '581586', '581587'],
#       dtype=object)

# %% [markdown]
# * coluna invoice_no, deve mudar seu tipo para int64

# %% [markdown]
# ## 2.4 Check NA

# %%
df.isna().sum()
# Out:
# invoice_no           0
# stock_code           0
# description       1454
# quantity             0
# invoice_date         0
# unit_price           0
# customer_id     135080
# country              0
# dtype: int64

# %%
(df.isna().sum() / 541909 ) *100
# Out:
# invoice_no       0.000000
# stock_code       0.000000
# description      0.268311
# quantity         0.000000
# invoice_date     0.000000
# unit_price       0.000000
# customer_id     24.926694
# country          0.000000
# dtype: float64

# %% [markdown]
# REFLEXÃO p/ trabalhar com os NANs
#
# **Objetivo do trabalhoh:** Usa a metodologia de clustering para segmentar clientes em grupos!
#
# Formas de tratar os NAN:
#
#     * Deletar ( df.dropna() )
#         * + (vantagem        -  Simples
#         * - (Desvantagem )   -  Perda de informação
#         * Goal               -  Depende da quantidade
#
#     * Preencher
#         * + (vantagem        -  Mantém o tamanho original dos dados
#         * - (Desvantagem )   -  Caso a distribuição n seja normal, pode fica com muito viés!
#         * Goal               -  Atrapalharia na segmentação e interpretação do cliente!
#
#     * Interpolar
#         * + (vantagem        -  Mantém a integridade de seres temporais
#         * - (Desvantagem )   -  Pode distorcer com informações falsas
#         * Goal               -  Segmentar o cliente errado no grupo, pois o mesmo pode aparecer mais de uma vez, com uma pequenas  diferança nas suas características.
#
#     * Modelos Estatísticos
#         * + (vantagem        -  Abordagem mais sofisticada
#         * - (Desvantagem )   -  Reque muito recurso do computador e pode ser impreciso
#         * Goal               -  Pode acumular muita informação incorreta!
#
# Conclusão: Melhor caminho, baseado na quantidade máximo de perda é 25% de perda de informação.

# %% [markdown]
# ## 2.5 Fillout NAN ou Null

# %% [markdown]
# colunas com NA description, customer_id

# %%
df.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   invoice_date  unit_price  customer_id         country
# 0    29-Nov-16        2.55      17850.0  United Kingdom
# 1    29-Nov-16        3.39      17850.0  United Kingdom
# 2    29-Nov-16        2.75      17850.0  United Kingdom
# 3    29-Nov-16        3.39      17850.0  United Kingdom
# 4    29-Nov-16        3.39      17850.0  United Kingdom

# %%
df['description'].unique()
# Out:
# array(['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN',
#        'CREAM CUPID HEARTS COAT HANGER', ..., 'lost',
#        'CREAM HANGING HEART T-LIGHT HOLDER',
#        'PAPER CRAFT , LITTLE BIRDIE'], dtype=object)

# %%
df['customer_id'].unique()
# Out:
# array([17850., 13047., 12583., ..., 13298., 14569., 12713.])

# %% [markdown]
# ##### Qual seria o plano
#     * customer_id - O id, ele traz uma identificação do cliente, contudo
#     * description - pode subtituir por "sem comentário"

# %% [markdown]
# ###### Tentativa 1 ( X )

# %%
df1 = df.dropna()

# %%
df1.isnull().sum()
# Out:
# invoice_no      0
# stock_code      0
# description     0
# quantity        0
# invoice_date    0
# unit_price      0
# customer_id     0
# country         0
# dtype: int64

# %% [markdown]
# ###### Tentativa 2

# %%
#df_missing     = df.loc[df1['customer_id'].isna(), :]
#df_not_missing = df.loc[~df1['customer_id'].isna(), :]

#create reference
#df_backup = pd.DataFrame(df_missing['invoice_no']).drop_duplicates()
#df_backup['customer_id'] = np.arange(19000, 19000 + len(df_backup), 1)

#merge original with reference dataframe
#df1 = pd.merge(df1, df_backup, on='invoice_no', how='left')

#coalesce 
#df1['customer_id'] = df1['customer_id_x'].combine_first(df1['customer_id_y'])

#drop extra columns
#df1 = df1.drop(columns=['customer_id_x', 'customer_id_y'], axis=1)
#df1.head()

# %% [markdown]
# ## 2.7 Change Type

# %%
df1.dtypes
# Out:
# invoice_no       object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# customer_id     float64
# country          object
# dtype: object

# %%
df1.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   invoice_date  unit_price  customer_id         country
# 0    29-Nov-16        2.55      17850.0  United Kingdom
# 1    29-Nov-16        3.39      17850.0  United Kingdom
# 2    29-Nov-16        2.75      17850.0  United Kingdom
# 3    29-Nov-16        3.39      17850.0  United Kingdom
# 4    29-Nov-16        3.39      17850.0  United Kingdom

# %%
# invoice_no
#df1['invoice_no']   = df1['invoice_no'].astype( int ) 

#invoice date
df1.loc[:, 'invoice_date'] = pd.to_datetime(df1.loc[:,'invoice_date'], format= '%d-%b-%y') 

#customer id
df1.loc[:, 'customer_id'] = df1.loc[:, 'customer_id'].astype(int)
df1.dtypes
# Out:
# invoice_no       object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# customer_id     float64
# country          object
# dtype: object

# %% [markdown]
#  ## 2.7 Descriptive Statistics

# %%
num_attributes = df1.select_dtypes( include = ['int64', 'int32', 'float64'] )
cat_attributes = df1.select_dtypes( exclude = ['int64', 'int32', 'float64', 'datetime64[ns]'] )

# %% [markdown]
# ## 2.7.1 Numerical Attributes

# %%
#central tendency - mean, median
ct1 = pd.DataFrame(num_attributes.apply(np.mean)).T
ct2 = pd.DataFrame(num_attributes.apply(np.median)).T

#dispersion 
d1 = pd.DataFrame(num_attributes.apply(np.std)).T
d2 = pd.DataFrame(num_attributes.apply(np.min)).T
d3 = pd.DataFrame(num_attributes.apply(np.max)).T
d4 = pd.DataFrame(num_attributes.apply(lambda x: x.max() - x.min())).T
d5 = pd.DataFrame(num_attributes.apply(lambda x: x.skew())).T
d6 = pd.DataFrame(num_attributes.apply(lambda x: x.kurtosis())).T

#concatenate
m1 = pd.concat([d2 ,d3, d4, ct1, ct2, d1, d5, d6]).T.reset_index()
m1 = m1.drop([2])
m1.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis' ]
m1
# Out:
#    attributes      min      max     range       mean  median         std  \
# 0    quantity -80995.0  80995.0  161990.0  12.061303    5.00  248.693064
# 1  unit_price      0.0  38970.0   38970.0   3.460471    1.95   69.315077
#
#          skew       kurtosis
# 0    0.182663   94317.563673
# 1  452.219019  246924.542988

# %% [markdown]
# ## 2.7.2 Categorical Attributes

# %%
cat_attributes.head()
# Out:
#   invoice_no stock_code                          description  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1     536365      71053                  WHITE METAL LANTERN
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#           invoice_date         country
# 0  2016-11-29 00:00:00  United Kingdom
# 1  2016-11-29 00:00:00  United Kingdom
# 2  2016-11-29 00:00:00  United Kingdom
# 3  2016-11-29 00:00:00  United Kingdom
# 4  2016-11-29 00:00:00  United Kingdom

# %%
df_letter_invoices = df1.loc[df1['invoice_no'].apply(lambda x: bool(re.search('[^0-9]+', x))), :]

#check if the number of invoices that contains letters are igual with negative quantity
print('Total number of invoices: {}'.format(len(df_letter_invoices)))
print('Total number of negative quantity: {}'.format(len(df_letter_invoices[df_letter_invoices['quantity'] < 0])))
# Out:
# Total number of invoices: 8905
# Total number of negative quantity: 8905

# %% [markdown]
# **Stock code**

# %%
cat_attributes.loc[cat_attributes['stock_code'].apply(lambda x: bool(re.search('^[a-zA-Z]+$', x))), 'stock_code']
# Out:
# 45        POST
# 141          D
# 386       POST
# 1123      POST
# 2239         M
#           ...
# 541216    POST
# 541541       M
# 541730    POST
# 541767    POST
# 541768    POST
# Name: stock_code, Length: 1774, dtype: object

# %%
df1.loc[cat_attributes['stock_code'].apply(lambda x: bool(re.search('^[a-zA-Z]+$', x))), :].head()
# Out:
#      invoice_no stock_code description  quantity         invoice_date  \
# 45       536370       POST     POSTAGE         3  2016-11-29 00:00:00
# 141     C536379          D    Discount        -1  2016-11-29 00:00:00
# 386      536403       POST     POSTAGE         1  2016-11-29 00:00:00
# 1123     536527       POST     POSTAGE         1  2016-11-29 00:00:00
# 2239     536569          M      Manual         1  2016-11-29 00:00:00
#
#       unit_price  customer_id         country
# 45         18.00      12583.0          France
# 141        27.50      14527.0  United Kingdom
# 386        15.00      12791.0     Netherlands
# 1123       18.00      12662.0         Germany
# 2239        1.25      16274.0  United Kingdom

# %% [markdown]
# ## 3.0 Filter Variables

# %%
df2 = df1

# %%
df2.describe()
# Out:
#             quantity     unit_price    customer_id
# count  406829.000000  406829.000000  406829.000000
# mean       12.061303       3.460471   15287.690570
# std       248.693370      69.315162    1713.600303
# min    -80995.000000       0.000000   12346.000000
# 25%         2.000000       1.250000   13953.000000
# 50%         5.000000       1.950000   15152.000000
# 75%        12.000000       3.750000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
#unit price > 0.0
#df2 = df2.loc[df2['unit_price'] > 0.04, :]

#stock code different of ['POST', 'D', 'M', 'PADS', 'DOT', 'CRUK']
#df2 = df2[~df2['stock_code'].isin(['POST', 'D', 'DOT', 'M', 'S', 'AMAZONFEE', 'm', 'DCGSSBOY','DCGSSGIRL', 'PADS', 'B', 'CRUK'])]

#description
df2.drop(columns='description', axis=1, inplace = True)

#map New Feacture
#df2 = df2[~df2['country'].isin(['European Community', 'Unspecified'])] # isin(comparado) se comparado for igual ao de fora retorna True
#A ideia nesse código de cima está mal feito, a ideia ao que parece é pegar 
#todos os paídes da europa e subtituir por 'European Community' e fora por 'Unspecified'
# uma forma de fazer isso é criar uma lista country_europa, depois é só 
# df2['europeu'] = df2['country'].apply(lambda x : 1 if x is in country_europa else 0 )

#bad users
#df2 = df2[~df2['customer_id'].isin([16446])] #user com numero muito grande de retornos 

#quantity - dividing in return and purchase 
returns = df2.loc[df2['quantity'] < 0, :]
purchases = df2.loc[df2['quantity'] >= 0, :]
# Out:
# /tmp/ipykernel_53900/2185533012.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns='description', axis=1, inplace = True)

# %% [markdown]
# # 4.0 Features Engineering

# %%
df3 = df2

# %%
# Image map mental

# %% [markdown]
# **Conjunto New Features**

# %%
# Conjunto New Features
# Nesse conjunto alguma alterações personalizadas ficaram disponível, pois pode conter linhas a menos do que o geral
df_ref = df3.drop(['invoice_no', 'stock_code', 'quantity', 'invoice_date','unit_price', 
                   'country'], axis=1).drop_duplicates(ignore_index=True)
df_ref.head()
# Out:
#    customer_id
# 0      17850.0
# 1      13047.0
# 2      12583.0
# 3      13748.0
# 4      15100.0

# %% [markdown]
# ## 4.1 Create Engineering

# %% [markdown]
# ### 4.1.1 Time

# %%
#year


# Convertendo a coluna para o formato datetime
df3['invoice_date'] = pd.to_datetime(df3['invoice_date'])

# .dt para extrair o ano, M
df3['year'] = df3['invoice_date'].dt.year


# month
df3['month'] = df3['invoice_date'].dt.month

df3['month_sin'] = df3['month'].apply(lambda x: np.sin( x* (2. * np.pi/12) ) )
df3['month_cos'] = df3['month'].apply(lambda x: np.cos( x* (2. * np.pi/12) ) )
# Out:
# /tmp/ipykernel_53900/819043007.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['invoice_date'] = pd.to_datetime(df3['invoice_date'])
# /tmp/ipykernel_53900/819043007.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['year'] = df3['invoice_date'].dt.year
# /tmp/ipykernel_53900/819043007.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['year'] = df3['invoice_date'].dt.year
# /tmp/ipykernel_53900/819043007.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['month'] = df3['invoice_date'].dt.month
# /tmp/ipykernel_53900/819043007.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['month_sin'] = df3['month'].apply(lambda x: np.sin( x* (2. * np.pi/12) ) )
# /tmp/ipykernel_53900/819043007.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['month_cos'] = df3['month'].apply(lambda x: np.cos( x* (2. * np.pi/12) ) )

# %% [markdown]
# ### 4.1.2 Gross Revenue

# %%
df3.head()
# Out:
#   invoice_no stock_code  quantity invoice_date  unit_price  customer_id  \
# 0     536365     85123A         6   2016-11-29        2.55      17850.0
# 1     536365      71053         6   2016-11-29        3.39      17850.0
# 2     536365     84406B         8   2016-11-29        2.75      17850.0
# 3     536365     84029G         6   2016-11-29        3.39      17850.0
# 4     536365     84029E         6   2016-11-29        3.39      17850.0
#
#           country  year  month  month_sin  month_cos
# 0  United Kingdom  2016     11       -0.5   0.866025
# 1  United Kingdom  2016     11       -0.5   0.866025
# 2  United Kingdom  2016     11       -0.5   0.866025
# 3  United Kingdom  2016     11       -0.5   0.866025
# 4  United Kingdom  2016     11       -0.5   0.866025

# %%
cancelled = df3[df3['quantity'] < 0]
cancelled.head()
# Out:
#     invoice_no stock_code  quantity invoice_date  unit_price  customer_id  \
# 141    C536379          D        -1   2016-11-29       27.50      14527.0
# 154    C536383     35004C        -1   2016-11-29        4.65      15311.0
# 235    C536391      22556       -12   2016-11-29        1.65      17548.0
# 236    C536391      21984       -24   2016-11-29        0.29      17548.0
# 237    C536391      21983       -24   2016-11-29        0.29      17548.0
#
#             country  year  month  month_sin  month_cos
# 141  United Kingdom  2016     11       -0.5   0.866025
# 154  United Kingdom  2016     11       -0.5   0.866025
# 235  United Kingdom  2016     11       -0.5   0.866025
# 236  United Kingdom  2016     11       -0.5   0.866025
# 237  United Kingdom  2016     11       -0.5   0.866025

# %%
df.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   invoice_date  unit_price  customer_id         country
# 0    29-Nov-16        2.55      17850.0  United Kingdom
# 1    29-Nov-16        3.39      17850.0  United Kingdom
# 2    29-Nov-16        2.75      17850.0  United Kingdom
# 3    29-Nov-16        3.39      17850.0  United Kingdom
# 4    29-Nov-16        3.39      17850.0  United Kingdom

# %%
df[df['description'].str.contains(',', na=False)]
# Out:
#        invoice_no stock_code                          description  quantity  \
# 109        536381      82567            AIRLINE LOUNGE,METAL SIGN         2
# 253        536394      21506           FANCY FONT BIRTHDAY CARD,         24
# 956        536520      22760               TRAY, BREAKFAST IN BED         1
# 1014       536520      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         1
# 1083       536524      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         6
# 1214       536531      22819            BIRTHDAY CARD, RETRO SPOT        24
# 1215       536531      21506           FANCY FONT BIRTHDAY CARD,         24
# 1257       536532      21506           FANCY FONT BIRTHDAY CARD,         12
# 1664       536544      22760               TRAY, BREAKFAST IN BED         1
# 1719       536544     35818P           ACRYLIC JEWEL ICICLE, PINK         1
# 1743       536544     79030D                     TUMBLER, BAROQUE         1
# 1744       536544     79030G                 TUMBLER, NEW ENGLAND         1
# 1750       536544     82613B       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 1751       536544     82613C       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 1922       536544      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 1950       536544      21507            ELEPHANT, BIRTHDAY CARD,          1
# 1980      C536548      22245         HOOK, 1 HANGER ,MAGIC GARDEN        -2
# 2104       536559     51014C               FEATHER PEN,COAL BLACK        24
# 2105       536559     51014L               FEATHER PEN,LIGHT PINK        12
# 2106       536559     51014L               FEATHER PEN,LIGHT PINK        12
# 2107       536559     51014C               FEATHER PEN,COAL BLACK        12
21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         4
# 6684       536975      22246           GARLAND, MAGIC GARDEN 1.8M        12
# 7336       537034     84247G             DECOUPAGE,GREETING CARD,        12
# 7503       537042      21112        SWISS ROLL TOWEL, PINK  SPOTS         1
# 7743       537052      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR        24
# 7826       537057     47310M           SMALL POP BOX,FUNKY MONKEY         1
# 8128       537126      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 8145       537126     79302M               ART LIGHTS,FUNK MONKEY         1
# 8219       537130      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 8388       537135     51014C               FEATHER PEN,COAL BLACK        12
# 8455       537136     79151B               SILICON CUBE 25W, BLUE         1
# 8465       537136     17107D  FLOWER FAIRY,5 SUMMER B'DRAW LINERS         2
# 8632       537141      21808        CHRISTMAS GARLAND STARS,TREES        12
# 8703       537144      21901                 KEY FOB , BACK DOOR          1
# 8704       537144      21900                       KEY FOB , SHED         2
# 8921       537155      21902               KEY FOB , FRONT  DOOR          1
# 8935       537156     75013B         STRING OF 8 BUTTERFLIES,PINK         4
# 9118       537192      21109    LARGE CAKE TOWEL, CHOCOLATE SPOTS         1
# 9131       537193      21900                       KEY FOB , SHED        20
# 9133       537193      21899              KEY FOB , GARAGE DESIGN        12
# 9188       537195      21899              KEY FOB , GARAGE DESIGN         1
# 9190       537195     82613B       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 9340       537199     84247G             DECOUPAGE,GREETING CARD,        12
# 9439       537201      22245         HOOK, 1 HANGER ,MAGIC GARDEN        12
# 9661       537209      21112        SWISS ROLL TOWEL, PINK  SPOTS         1
# 9779       537217      22849         BREAD BIN, DINER STYLE, MINT         4
# 9780       537217      22847        BREAD BIN, DINER STYLE, IVORY         4
# 9784       537218      21506           FANCY FONT BIRTHDAY CARD,         12
# 9804       537219      21899              KEY FOB , GARAGE DESIGN         1
# 9805       537219      21901                 KEY FOB , BACK DOOR          1
# 9806       537219      21902               KEY FOB , FRONT  DOOR          3
# 9807       537219      21900                       KEY FOB , SHED         2
# 9883       537222      21900                       KEY FOB , SHED         1
# 10006      537224      21899              KEY FOB , GARAGE DESIGN         2
# 10007      537224      21901                 KEY FOB , BACK DOOR          1
# 10015      537224      21899              KEY FOB , GARAGE DESIGN         1
# 10016      537224      21901                 KEY FOB , BACK DOOR          4
# 10017      537224      21900                       KEY FOB , SHED         3
# 10027      537224      21901                 KEY FOB , BACK DOOR          1
# 10190      537231      21109    LARGE CAKE TOWEL, CHOCOLATE SPOTS         2
# 10214      537236      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         8
# 10277      537237      21112        SWISS ROLL TOWEL, PINK  SPOTS         1
# 10326      537237      21506           FANCY FONT BIRTHDAY CARD,          2
# 10379      537237      21900                       KEY FOB , SHED         1
# 10450      537237      22165  DIAMANTE HEART SHAPED WALL MIRROR,          2
# 10480      537237      22285      DECORATION HEN ON NEST, HANGING         1
# 10693      537237     51014C               FEATHER PEN,COAL BLACK         1
# 10702      537237     79302M               ART LIGHTS,FUNK MONKEY         1
# 10707      537237      82567            AIRLINE LOUNGE,METAL SIGN         1
# 11027      537240      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         2
# 11044      537240      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 11136      537240      21900                       KEY FOB , SHED         3
# 11228      537240      22285      DECORATION HEN ON NEST, HANGING         1
# 11291      537240      82567            AIRLINE LOUNGE,METAL SIGN         1
# 11296      537240     82613B       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 11297      537240     82613C       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 11484      537248     79030D                     TUMBLER, BAROQUE         6
# 11489      537250      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         4
# 11730      537265      21506           FANCY FONT BIRTHDAY CARD,         12
# 11745      537265      21506           FANCY FONT BIRTHDAY CARD,         12
# 11929      537351      22985         WRAP, BILLBOARD FONTS DESIGN        25
# 12011      537362     79030G                 TUMBLER, NEW ENGLAND         2
# 12183      537370      21506           FANCY FONT BIRTHDAY CARD,         12
# 12370      537375      21901                 KEY FOB , BACK DOOR          3
# 12371      537375      21900                       KEY FOB , SHED         3
# 12372      537375      21899              KEY FOB , GARAGE DESIGN         3
# 12571      537387      22245         HOOK, 1 HANGER ,MAGIC GARDEN        12
# 12804      537396     75013B         STRING OF 8 BUTTERFLIES,PINK         1
# 12974      537405     79302M               ART LIGHTS,FUNK MONKEY         1
# 13306      537434      21109    LARGE CAKE TOWEL, CHOCOLATE SPOTS         1
# 13307      537434      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         1
# 13370      537434      21506           FANCY FONT BIRTHDAY CARD,          1
# 13371      537434      21507            ELEPHANT, BIRTHDAY CARD,          2
# 13431      537434      21899              KEY FOB , GARAGE DESIGN         1
# 13432      537434      21901                 KEY FOB , BACK DOOR          2
# 13504      537434      22165  DIAMANTE HEART SHAPED WALL MIRROR,          2
# 13770      537434     37462E                    PET MUG, GOLDFISH         2
# 13803      537434     82613B       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 14020      537442      21506           FANCY FONT BIRTHDAY CARD,          1
# 14135      537463      21506           FANCY FONT BIRTHDAY CARD,         12
# 14330      537523      21109    LARGE CAKE TOWEL, CHOCOLATE SPOTS         2
# 14441      537592      21900                       KEY FOB , SHED        24
# 14442      537592      21901                 KEY FOB , BACK DOOR         24
# 14491      537595      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 15209      537638      21899              KEY FOB , GARAGE DESIGN         1
# 15210      537638      21900                       KEY FOB , SHED         1
# 15211      537638      21901                 KEY FOB , BACK DOOR          1
# 15278      537638      22165  DIAMANTE HEART SHAPED WALL MIRROR,          3
# 15541      537638      82567            AIRLINE LOUNGE,METAL SIGN         1
# 15544      537638     82613B       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 15813      537641      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         2
# 16142      537645      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         2
# 16449      537666      22245         HOOK, 1 HANGER ,MAGIC GARDEN         1
# 16677      537666      82567            AIRLINE LOUNGE,METAL SIGN         1
# 16690      537666     84251B         GREETING CARD, STICKY GORDON         1
# 16966      537666      22165  DIAMANTE HEART SHAPED WALL MIRROR,          1
# 17273      537692      82567            AIRLINE LOUNGE,METAL SIGN         2
# 17813      537781      21506           FANCY FONT BIRTHDAY CARD,         12
# 18065      537794      21506           FANCY FONT BIRTHDAY CARD,         12
# 18153      537802      21462        NURSERY A,B,C PAINTED LETTERS         2
# 18367      537822      21112        SWISS ROLL TOWEL, PINK  SPOTS         6
# 18414      537823     37462E                    PET MUG, GOLDFISH         1
# 18423      537823     51014A                 FEATHER PEN,HOT PINK         1
# 18444      537823     82613B       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 18445      537823     82613C       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 18455      537823     84251B         GREETING CARD, STICKY GORDON         1
# 18456      537823     84251G     GREETING CARD, OVERCROWDED POOL.         1
# 18605      537823      21112        SWISS ROLL TOWEL, PINK  SPOTS         2
# 18705      537823      21899              KEY FOB , GARAGE DESIGN         2
# 18706      537823      21901                 KEY FOB , BACK DOOR          1
# 18962      537823      22819            BIRTHDAY CARD, RETRO SPOT         4
# 19052      537828      22245         HOOK, 1 HANGER ,MAGIC GARDEN        12
# 19191      537844      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         1
# 19532      537868      21506           FANCY FONT BIRTHDAY CARD,         12
# 20139      538011      21899              KEY FOB , GARAGE DESIGN        25
# 20140      538011      21900                       KEY FOB , SHED        22
# 20141      538011      21901                 KEY FOB , BACK DOOR         19
# 20142      538011      21902               KEY FOB , FRONT  DOOR         16
# 20478      538056      21506           FANCY FONT BIRTHDAY CARD,         12
# 20541      538064      21899              KEY FOB , GARAGE DESIGN         4
# 20542      538064      21900                       KEY FOB , SHED         4
# 20543      538064      21901                 KEY FOB , BACK DOOR          6
# 20544      538064      21902               KEY FOB , FRONT  DOOR          6
# 20747      538071      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         2
# 20845      538071      21899              KEY FOB , GARAGE DESIGN         1
# 20846      538071      21900                       KEY FOB , SHED         1
# 20847      538071      21901                 KEY FOB , BACK DOOR          1
# 20848      538071      21902               KEY FOB , FRONT  DOOR          1
# 20919      538071      22165  DIAMANTE HEART SHAPED WALL MIRROR,          3
# 21185      538071     51014A                 FEATHER PEN,HOT PINK         3
# 21206      538071      82567            AIRLINE LOUNGE,METAL SIGN         1
# 21210      538071     82613B       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 21211      538071     82613C       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 21226      538071     84247G             DECOUPAGE,GREETING CARD,         1
# 21851      538148      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 22263      538156     17107D  FLOWER FAIRY,5 SUMMER B'DRAW LINERS        10
# 22643      538177      21109    LARGE CAKE TOWEL, CHOCOLATE SPOTS         1
# 22662      538177      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 22737      538177      21899              KEY FOB , GARAGE DESIGN         1
# 22738      538177      21900                       KEY FOB , SHED         1
# 22739      538177      21901                 KEY FOB , BACK DOOR          1
# 22740      538177      21902               KEY FOB , FRONT  DOOR          1
# 22782      538177      22165  DIAMANTE HEART SHAPED WALL MIRROR,          1
# 22800      538177      22245         HOOK, 1 HANGER ,MAGIC GARDEN         1
# 22809      538177      22285      DECORATION HEN ON NEST, HANGING         1
# 23029      538177      82567            AIRLINE LOUNGE,METAL SIGN         1
# 23285      538196      21507            ELEPHANT, BIRTHDAY CARD,         12
# 23338      538198      22819            BIRTHDAY CARD, RETRO SPOT        12
# 23522      538205     75013B         STRING OF 8 BUTTERFLIES,PINK         2
# 24237      538346      82567            AIRLINE LOUNGE,METAL SIGN         6
# 24366      538349      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 24400      538349      21507            ELEPHANT, BIRTHDAY CARD,          2
# 24457      538349      21901                 KEY FOB , BACK DOOR          1
# 24547      538349      22286  DECORATION , WOBBLY RABBIT , METAL          1
# 24548      538349      22287  DECORATION , WOBBLY CHICKEN, METAL          1
# 24708      538349      22819            BIRTHDAY CARD, RETRO SPOT         2
# 24778      538349     51014A                 FEATHER PEN,HOT PINK         1
# 24779      538349     51014C               FEATHER PEN,COAL BLACK         1
# 24798      538349     82613B       METAL SIGN,CUPCAKE SINGLE HOOK         2
# 24807      538349     84251B         GREETING CARD, STICKY GORDON         1
# 25514      538371      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 25550      538371      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 25567      538374      21900                       KEY FOB , SHED         1
# 25755      538397      21507            ELEPHANT, BIRTHDAY CARD,         72
# 25789      538397      22245         HOOK, 1 HANGER ,MAGIC GARDEN        48
# 25894      538419      21506           FANCY FONT BIRTHDAY CARD,         12
# 25980      538449      82567            AIRLINE LOUNGE,METAL SIGN         1
# 26074      538488     17107D  FLOWER FAIRY,5 SUMMER B'DRAW LINERS         3
# 26441      538513      21462        NURSERY A,B,C PAINTED LETTERS         2
# 26563      538517      22760               TRAY, BREAKFAST IN BED         1
# 26742      538521      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         4
# 26744      538521     82011A      BATHROOM SCALES, TROPICAL BEACH         2
# 26847      538524      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 26876      538524      21507            ELEPHANT, BIRTHDAY CARD,          1
# 26913      538524      21900                       KEY FOB , SHED         2
# 26914      538524      21901                 KEY FOB , BACK DOOR          1
# 26915      538524      21902               KEY FOB , FRONT  DOOR          1
# 27271      538525      21506           FANCY FONT BIRTHDAY CARD,         24
# 27273      538525      22819            BIRTHDAY CARD, RETRO SPOT        12
# 27342      538532      22760               TRAY, BREAKFAST IN BED         2
# 27492      538566      21899              KEY FOB , GARAGE DESIGN         1
# 27493      538566      21901                 KEY FOB , BACK DOOR          1
# 27541      538566      22165  DIAMANTE HEART SHAPED WALL MIRROR,          2
# 27560      538566      22245         HOOK, 1 HANGER ,MAGIC GARDEN         1
# 27689      538566      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 28216      538630      21109    LARGE CAKE TOWEL, CHOCOLATE SPOTS         2
# 28218      538630      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         6
# 28219      538630      21112        SWISS ROLL TOWEL, PINK  SPOTS         6
# 28353      538635      82567            AIRLINE LOUNGE,METAL SIGN         1
# 28595      538646      22760               TRAY, BREAKFAST IN BED         5
# 28861      538662      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS        24
# 28862      538662      21112        SWISS ROLL TOWEL, PINK  SPOTS        24
# 29224      538714     51014L               FEATHER PEN,LIGHT PINK         1
# 29333      538744      82567            AIRLINE LOUNGE,METAL SIGN         2
# 29414      538795      22760               TRAY, BREAKFAST IN BED         3
# 29506      538801      21112        SWISS ROLL TOWEL, PINK  SPOTS        24
# 29520      538801      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS        24
# 29576      538808      21507            ELEPHANT, BIRTHDAY CARD,         24
# 29805      538826      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS        12
# 29810      538826      21112        SWISS ROLL TOWEL, PINK  SPOTS        12
# 29818      538827     82613C       METAL SIGN,CUPCAKE SINGLE HOOK        20
# 29819      538827     82613B       METAL SIGN,CUPCAKE SINGLE HOOK        20
# 29860      538827      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS        24
# 29873      538827     79302M               ART LIGHTS,FUNK MONKEY        20
# 29889      538827     85159B          WHITE TEA,COFFEE,SUGAR JARS        12
# 29890      538827     85159A          BLACK TEA,COFFEE,SUGAR JARS        12
# 30230      538853      22285      DECORATION HEN ON NEST, HANGING         3
# 30274      538853     75013B         STRING OF 8 BUTTERFLIES,PINK         3
# 30435      538866     79302M               ART LIGHTS,FUNK MONKEY         1
# 30789      538880      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 30918      538883      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 31110      538895     82613B       METAL SIGN,CUPCAKE SINGLE HOOK        20
# 31187      538903      22760               TRAY, BREAKFAST IN BED         1
# 31543      538993     35817P         ACRYLIC JEWEL SNOWFLAKE,PINK         6
# 31798      539014      21808        CHRISTMAS GARLAND STARS,TREES        12
# 31891      539019     17107D  FLOWER FAIRY,5 SUMMER B'DRAW LINERS         4
# 31968      539036      21112        SWISS ROLL TOWEL, PINK  SPOTS        24
# 31986      539038     82613B       METAL SIGN,CUPCAKE SINGLE HOOK        20
# 31987      539038     82613C       METAL SIGN,CUPCAKE SINGLE HOOK        20
# 32055      539039     79302M               ART LIGHTS,FUNK MONKEY         3
# 32223      539047      22285      DECORATION HEN ON NEST, HANGING        24
# 32265      539050      21901                 KEY FOB , BACK DOOR          1
# 32266      539050      21900                       KEY FOB , SHED         1
# 32359      539053      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         1
# 32647      539099      22819            BIRTHDAY CARD, RETRO SPOT        12
# 32891      539196     79030D                     TUMBLER, BAROQUE        12
# 32892      539196     17107D  FLOWER FAIRY,5 SUMMER B'DRAW LINERS        12
# 33349      539250      21112        SWISS ROLL TOWEL, PINK  SPOTS        24
# 33350      539250      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS        24
# 33449      539256      21506           FANCY FONT BIRTHDAY CARD,         12
# 33551      539262     85159A          BLACK TEA,COFFEE,SUGAR JARS        12
# 33552      539262     85159B          WHITE TEA,COFFEE,SUGAR JARS        12
# 33615      539272      21506           FANCY FONT BIRTHDAY CARD,         12
# 33618     C539273      22760               TRAY, BREAKFAST IN BED        -1
# 33792      539294      21112        SWISS ROLL TOWEL, PINK  SPOTS         1
# 33793      539294      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         1
# 33905      539307      21112        SWISS ROLL TOWEL, PINK  SPOTS       120
# 33979      539311     82613B       METAL SIGN,CUPCAKE SINGLE HOOK        40
# 33980      539311     82613C       METAL SIGN,CUPCAKE SINGLE HOOK        40
# 34393      539338      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR        24
# 34723      539421     51014A                 FEATHER PEN,HOT PINK        12
# 34724      539421     51014L               FEATHER PEN,LIGHT PINK        12
# 34845      539434      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         2
# 34846      539434      21112        SWISS ROLL TOWEL, PINK  SPOTS         1
# 34860      539434      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 34891      539434      21507            ELEPHANT, BIRTHDAY CARD,          1
# 34930      539434      21902               KEY FOB , FRONT  DOOR          2
# 35003      539434      22286  DECORATION , WOBBLY RABBIT , METAL          1
# 35004      539434      22287  DECORATION , WOBBLY CHICKEN, METAL          1
# 35263      539436      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         2
# 35287      539436      21506           FANCY FONT BIRTHDAY CARD,          4
# 35288      539436      21507            ELEPHANT, BIRTHDAY CARD,          1
# 35324      539436      21899              KEY FOB , GARAGE DESIGN         2
# 35325      539436      21901                 KEY FOB , BACK DOOR          1
# 35371      539436      22165  DIAMANTE HEART SHAPED WALL MIRROR,          2
# 35495      539436      22760               TRAY, BREAKFAST IN BED         1
# 35548      539436     51014A                 FEATHER PEN,HOT PINK         2
# 35563      539436      82567            AIRLINE LOUNGE,METAL SIGN         1
# 35778      539437      21900                       KEY FOB , SHED         2
# 35779      539437      21901                 KEY FOB , BACK DOOR          1
# 35780      539437      21902               KEY FOB , FRONT  DOOR          1
# 35834      539437      22165  DIAMANTE HEART SHAPED WALL MIRROR,          1
# 35848      539437      22206            MUG , DOTCOMGIFTSHOP.COM          1
# 36035      539437     47310M           SMALL POP BOX,FUNKY MONKEY         1
# 36061      539437      82567            AIRLINE LOUNGE,METAL SIGN         1
# 36066      539437     82613B       METAL SIGN,CUPCAKE SINGLE HOOK         2
# 36067      539437     82613C       METAL SIGN,CUPCAKE SINGLE HOOK         3
# 36386      539451      82567            AIRLINE LOUNGE,METAL SIGN         2
# 36547      539451      21507            ELEPHANT, BIRTHDAY CARD,          1
# 36588      539451      21899              KEY FOB , GARAGE DESIGN         1
# 36791      539453      22245         HOOK, 1 HANGER ,MAGIC GARDEN         1
# 36987      539453     84247G             DECOUPAGE,GREETING CARD,         1
# 37116      539453      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         2
# 37451      539466     82613B       METAL SIGN,CUPCAKE SINGLE HOOK        20
# 37571      539471      21506           FANCY FONT BIRTHDAY CARD,         12
# 37572      539471      21506           FANCY FONT BIRTHDAY CARD,         12
# 37585      539471      22286  DECORATION , WOBBLY RABBIT , METAL          2
# 37763      539477     84247G             DECOUPAGE,GREETING CARD,        12
# 37764      539477     84249A      GREETING CARD,SQUARE, DOUGHNUTS        12
# 37915      539488      21506           FANCY FONT BIRTHDAY CARD,         12
# 38054      539492      22165  DIAMANTE HEART SHAPED WALL MIRROR,          3
# 38193      539492     37462E                    PET MUG, GOLDFISH         1
# 38212      539492      82567            AIRLINE LOUNGE,METAL SIGN         1
# 38252      539493      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         1
# 38535      539581      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         4
# 38556      539586      21112        SWISS ROLL TOWEL, PINK  SPOTS        24
# 38557      539586      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS        24
# 38875      539595      22245         HOOK, 1 HANGER ,MAGIC GARDEN         1
# 38968      539607      21506           FANCY FONT BIRTHDAY CARD,         12
# 39100      539631      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 39130      539631      21899              KEY FOB , GARAGE DESIGN         1
# 39131      539631      21901                 KEY FOB , BACK DOOR          1
# 39257      539631     35819B           ACRYLIC HANGING JEWEL,BLUE         1
# 39263      539631     51014C               FEATHER PEN,COAL BLACK         1
# 39386      539641      82567            AIRLINE LOUNGE,METAL SIGN         1
# 39520      539649      22985         WRAP, BILLBOARD FONTS DESIGN         1
# 39554      539653     82613B       METAL SIGN,CUPCAKE SINGLE HOOK        20
# 39555      539653     82613A       METAL SIGN,CUPCAKE SINGLE HOOK        20
# 39565      539653     82613C       METAL SIGN,CUPCAKE SINGLE HOOK        20
# 39605      539654      82567            AIRLINE LOUNGE,METAL SIGN        12
# 39874      539708     51014C               FEATHER PEN,COAL BLACK         2
# 39879      539708      82567            AIRLINE LOUNGE,METAL SIGN         1
# 39936      539718      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 39951      539718      21507            ELEPHANT, BIRTHDAY CARD,          1
# 40034      539718     84247G             DECOUPAGE,GREETING CARD,         2
# 40055     C539719     82613C       METAL SIGN,CUPCAKE SINGLE HOOK       -20
# 40056     C539719     82613B       METAL SIGN,CUPCAKE SINGLE HOOK       -20
# 40156      539728      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         6
# 40217      539731      21112        SWISS ROLL TOWEL, PINK  SPOTS        96
# 40263      539735      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 40367      539736      82567            AIRLINE LOUNGE,METAL SIGN         1
# 40398      539737      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 40426      539737      22165  DIAMANTE HEART SHAPED WALL MIRROR,          2
# 40485      539737     82613b       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 40486      539737     82613c       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 40598      539739      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         2
# 40715      539740      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 40726      539740      22165  DIAMANTE HEART SHAPED WALL MIRROR,          1
# 40763      539741     82613b       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 40764      539741     82613c       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 40846      539744      82567            AIRLINE LOUNGE,METAL SIGN         1
# 40881      539745      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         3
# 41211      539760     51014A                 FEATHER PEN,HOT PINK        12
# 41214      539760     51014C               FEATHER PEN,COAL BLACK        12
# 41229      539761      21112        SWISS ROLL TOWEL, PINK  SPOTS        24
# 41230      539761      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS        24
# 41329      539829     82613B       METAL SIGN,CUPCAKE SINGLE HOOK        20
# 41572      539933     82613B       METAL SIGN,CUPCAKE SINGLE HOOK         8
# 41573      539933     82613C       METAL SIGN,CUPCAKE SINGLE HOOK         8
# 41601      539933      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         4
# 41792      539958      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         3
# 41825      539958      21112        SWISS ROLL TOWEL, PINK  SPOTS         5
# 41843      539958      21507            ELEPHANT, BIRTHDAY CARD,          1
# 42155      539958      22760               TRAY, BREAKFAST IN BED         1
# 42161      539958      22819            BIRTHDAY CARD, RETRO SPOT        36
# 42193      539958     47310M           SMALL POP BOX,FUNKY MONKEY         6
# 42211      539958     82613B       METAL SIGN,CUPCAKE SINGLE HOOK        15
# 42212      539958     82613C       METAL SIGN,CUPCAKE SINGLE HOOK        11
# 42221      539958     84251B         GREETING CARD, STICKY GORDON         5
# 42222      539958     84251C          GREETING CARD, TWO SISTERS.        13
# 42223      539958     84251G     GREETING CARD, OVERCROWDED POOL.         5
# 42413      539988     82613B       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 42414      539988     82613A       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 42415      539988     82613C       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 42592      540013      21901                 KEY FOB , BACK DOOR          2
# 42593      540013      21900                       KEY FOB , SHED         5
# 42594      540013      21899              KEY FOB , GARAGE DESIGN         6
# 42659      540015      22985         WRAP, BILLBOARD FONTS DESIGN        25
# 42709      540017     82613C       METAL SIGN,CUPCAKE SINGLE HOOK        20
# 42738      540019      21899              KEY FOB , GARAGE DESIGN        24
# 42739      540019      21900                       KEY FOB , SHED        24
# 42740      540019      21901                 KEY FOB , BACK DOOR         24
# 43021      540026      22819            BIRTHDAY CARD, RETRO SPOT        22
# 43053      540026     47310M           SMALL POP BOX,FUNKY MONKEY         7
# 43093      540026      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         6
# 43094      540026      21112        SWISS ROLL TOWEL, PINK  SPOTS         6
# 43122      540026      21507            ELEPHANT, BIRTHDAY CARD,          1
# 43187      540026     82613B       METAL SIGN,CUPCAKE SINGLE HOOK        17
# 43188      540026     82613C       METAL SIGN,CUPCAKE SINGLE HOOK        14
# 43197      540026     84251B         GREETING CARD, STICKY GORDON         4
# 43198      540026     84251C          GREETING CARD, TWO SISTERS.        10
# 43199      540026     84251G     GREETING CARD, OVERCROWDED POOL.         4
# 43298      540027     82613B       METAL SIGN,CUPCAKE SINGLE HOOK        20
# 43299      540027     82613C       METAL SIGN,CUPCAKE SINGLE HOOK        20
# 43310      540027      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         4
# 43494      540093      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 43522      540095      22985         WRAP, BILLBOARD FONTS DESIGN        25
# 43599      540098      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 43625      540099      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         4
# 43726      540120      22245         HOOK, 1 HANGER ,MAGIC GARDEN        48
# 43739      540121      22245         HOOK, 1 HANGER ,MAGIC GARDEN        12
# 43766      540122     85159B          WHITE TEA,COFFEE,SUGAR JARS        48
# 43769      540126      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS        96
# 43770      540126      21112        SWISS ROLL TOWEL, PINK  SPOTS        96
# 43965      540154      22819            BIRTHDAY CARD, RETRO SPOT        10
# 43989      540154     47310M           SMALL POP BOX,FUNKY MONKEY         1
# 44002      540154     82613B       METAL SIGN,CUPCAKE SINGLE HOOK         2
# 44003      540154     82613C       METAL SIGN,CUPCAKE SINGLE HOOK         2
# 44007      540154     84251C          GREETING CARD, TWO SISTERS.         3
# 44121      540154      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         2
# 44122      540154      21112        SWISS ROLL TOWEL, PINK  SPOTS         4
# 44188      540157     82613C       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 44189      540157      21899              KEY FOB , GARAGE DESIGN         1
# 44258      540163      21506           FANCY FONT BIRTHDAY CARD,         24
# 44259      540163      21507            ELEPHANT, BIRTHDAY CARD,         12
# 44266      540163      22819            BIRTHDAY CARD, RETRO SPOT        12
# 44274      540163     84247G             DECOUPAGE,GREETING CARD,        12
# 44317      540167     85159A          BLACK TEA,COFFEE,SUGAR JARS        12
# 44372      540168      22245         HOOK, 1 HANGER ,MAGIC GARDEN         6
# 44575      540183      22245         HOOK, 1 HANGER ,MAGIC GARDEN        12
# 44587      540183      21507            ELEPHANT, BIRTHDAY CARD,         12
# 44638      540187      22819            BIRTHDAY CARD, RETRO SPOT        12
# 44644      540187      21507            ELEPHANT, BIRTHDAY CARD,         12
# 44697      540188      22985         WRAP, BILLBOARD FONTS DESIGN        25
# 44698      540188     51014C               FEATHER PEN,COAL BLACK        12
# 44704      540238      21112        SWISS ROLL TOWEL, PINK  SPOTS         2
# 44733      540238      22819            BIRTHDAY CARD, RETRO SPOT         4
# 44736      540238     82613B       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 44737      540238     82613C       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 44739      540238     84251C          GREETING CARD, TWO SISTERS.         2
# 44761      540238      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         2
# 44855      540240     85159A          BLACK TEA,COFFEE,SUGAR JARS        12
# 44856      540240     85159B          WHITE TEA,COFFEE,SUGAR JARS        12
# 44987      540247      22286  DECORATION , WOBBLY RABBIT , METAL          1
# 45080      540247      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 45263      540255      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         1
# 45264      540255      21112        SWISS ROLL TOWEL, PINK  SPOTS         2
# 45307      540255      22819            BIRTHDAY CARD, RETRO SPOT         6
# 45327      540255     82613C       METAL SIGN,CUPCAKE SINGLE HOOK         1
# 45333      540255     84251B         GREETING CARD, STICKY GORDON         3
# 45334      540255     84251C          GREETING CARD, TWO SISTERS.         4
# 45335      540255     84251G     GREETING CARD, OVERCROWDED POOL.         1
# 45352      540255      22245         HOOK, 1 HANGER ,MAGIC GARDEN         1
# 45418      540259     82613C       METAL SIGN,CUPCAKE SINGLE HOOK        20
# 45437      540260      82567            AIRLINE LOUNGE,METAL SIGN         6
# 45450      540260      21507            ELEPHANT, BIRTHDAY CARD,         24
# 45636      540273     51014L               FEATHER PEN,LIGHT PINK        72
# 45637      540273     51014A                 FEATHER PEN,HOT PINK        72
# 46156      540352     47310M           SMALL POP BOX,FUNKY MONKEY         1
# 46170      540352     82613B       METAL SIGN,CUPCAKE SINGLE HOOK         9
# 46171      540352     82613C       METAL SIGN,CUPCAKE SINGLE HOOK        13
# 46185      540352      22165  DIAMANTE HEART SHAPED WALL MIRROR,          2
# 46203      540352      22245         HOOK, 1 HANGER ,MAGIC GARDEN         1
# 46226      540352     84251B         GREETING CARD, STICKY GORDON         2
# 46227      540352     84251C          GREETING CARD, TWO SISTERS.         3
# 46228      540352     84251G     GREETING CARD, OVERCROWDED POOL.         1
# 46269      540352      21902               KEY FOB , FRONT  DOOR          1
# 46386      540352      22819            BIRTHDAY CARD, RETRO SPOT         5
# 46411      540352      21112        SWISS ROLL TOWEL, PINK  SPOTS         1
# 46417      540352      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 46490      540353      21900                       KEY FOB , SHED         4
# 46491      540353      21899              KEY FOB , GARAGE DESIGN         3
# 46743      540359     51014A                 FEATHER PEN,HOT PINK        12
# 46826      540364     85159B          WHITE TEA,COFFEE,SUGAR JARS         3
# 47284      540404     16156L                       WRAP, CAROUSEL        25
# 47498      540418      22819            BIRTHDAY CARD, RETRO SPOT        10
# 47507      540418     84251B         GREETING CARD, STICKY GORDON         1
# 47530      540418      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         5
# 47531      540418      21112        SWISS ROLL TOWEL, PINK  SPOTS         7
# 47551      540418      21506           FANCY FONT BIRTHDAY CARD,          1
# 47577      540418      22165  DIAMANTE HEART SHAPED WALL MIRROR,          1
# 47593      540418     84251C          GREETING CARD, TWO SISTERS.         3
# 47594      540418     84251G     GREETING CARD, OVERCROWDED POOL.         4
# 47598      540418     82613B       METAL SIGN,CUPCAKE SINGLE HOOK         3
# 47599      540418     82613C       METAL SIGN,CUPCAKE SINGLE HOOK         4
# 47861      540453      22819            BIRTHDAY CARD, RETRO SPOT        12
# 48007      540458      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         4
# 48046      540458      22985         WRAP, BILLBOARD FONTS DESIGN        25
# 48088      540460     84251B         GREETING CARD, STICKY GORDON        12
# 48089      540460     84251G     GREETING CARD, OVERCROWDED POOL.        12
# 48168      540464      22245         HOOK, 1 HANGER ,MAGIC GARDEN        24
# 48220      540468     84251B         GREETING CARD, STICKY GORDON         1
# 48221      540468     84251C          GREETING CARD, TWO SISTERS.         1
# 48239      540468      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         3
# 48257      540468      22819            BIRTHDAY CARD, RETRO SPOT        19
# 48278      540468     47310M           SMALL POP BOX,FUNKY MONKEY         2
# 48289      540468     51014C               FEATHER PEN,COAL BLACK         1
# 48293      540468     82613B       METAL SIGN,CUPCAKE SINGLE HOOK         4
# 48294      540468     82613C       METAL SIGN,CUPCAKE SINGLE HOOK         5
# 48414      540468      22165  DIAMANTE HEART SHAPED WALL MIRROR,          2
# 48544      540469     84251B         GREETING CARD, STICKY GORDON        12
# 48545      540469     84251C          GREETING CARD, TWO SISTERS.        12
# 48596      540469     75013B         STRING OF 8 BUTTERFLIES,PINK         6
# 48606      540469     51014L               FEATHER PEN,LIGHT PINK        12
# 48607      540469     51014A                 FEATHER PEN,HOT PINK        12
# 48636     C540470     85159B          WHITE TEA,COFFEE,SUGAR JARS        -2
# 48653      540471      21506           FANCY FONT BIRTHDAY CARD,         12
# 48654      540471      21507            ELEPHANT, BIRTHDAY CARD,         12
# 48841      540477      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS        24
# 48851      540477      21112        SWISS ROLL TOWEL, PINK  SPOTS        24
# 49012      540496      22819            BIRTHDAY CARD, RETRO SPOT        12
# 49013      540496      21506           FANCY FONT BIRTHDAY CARD,         12
# 49081      540501     82613B       METAL SIGN,CUPCAKE SINGLE HOOK        20
# 49082      540501     82613C       METAL SIGN,CUPCAKE SINGLE HOOK        20
# 49099      540501      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS        24
# 49100      540501      21112        SWISS ROLL TOWEL, PINK  SPOTS        24
# 49168      540505      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         4
# 49197      540506      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         2
# 49202      540506      21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR         1
# 49281      540509      22985         WRAP, BILLBOARD FONTS DESIGN        25
# 49472      540517     51014C               FEATHER PEN,COAL BLACK        12
# 49473      540517     51014A                 FEATHER PEN,HOT PINK        12
# 49538      540520      21506           FANCY FONT BIRTHDAY CARD,         12
# 49687      540526     51014C               FEATHER PEN,COAL BLACK        12
# 49888      540537      21900                       KEY FOB , SHED         3
# 50299      540551      21111   SWISS ROLL TOWEL, CHOCOLATE  SPOTS         5
# 50300      540551      21112        SWISS ROLL TOWEL, PINK  SPOTS         6
# 50328      540551      21506           FANCY FONT BIRTHDAY CARD,          1
# 50414      540551      22165  DIAMANTE HEART SHAPED WALL MIRROR,          1
# 50433      540551      22245         HOOK, 1 HANGER ,MAGIC GARDEN         2
# 50530      540551      22819            BIRTHDAY CARD, RETRO SPOT        11
# 50563      540551     47310M           SMALL POP BOX,FUNKY MONKEY         1
# 50571      540551     51014A                 FEATHER PEN,HOT PINK         2
# 50572      540551     51014L               FEATHER PEN,LIGHT PINK         1
# 50583      540551      82567            AIRLINE LOUNGE,METAL SIGN         1
# 50589      540551     82613B       METAL SIGN,CUPCAKE SINGLE HOOK         8
# 50590      540551     82613C       METAL SIGN,CUPCAKE SINGLE HOOK         6
# 50598      540551     84251B         GREETING CARD, STICKY GORDON         7
# 50599      540551     84251C          GREETING CARD, TWO SISTERS.         4
# 50766      540552     82613C       METAL SIGN,CUPCAKE SINGLE HOOK        20
# 50849      540564      22617                 mouldy, thrown away.     -2600
# 50971      540595      21506           FANCY FONT BIRTHDAY CARD,         12
# 50996      540604     84247G             DECOUPAGE,GREETING CARD,        12
# 51058      540639      21507            ELEPHANT, BIRTHDAY CARD,         24
# 51203      540645      21506           FANCY FONT BIRTHDAY CARD,         24
# 51206      540646     82613B       METAL SIGN,CUPCAKE SINGLE HOOK         2
# 51207      540646     82613C       METAL SIGN,CUPCAKE SINGLE HOOK         2
# 51233      540646      21112        SWISS ROLL TOWEL, PINK  SPOTS         2
# 51239      540646     84251C          GREETING CARD, TWO SISTERS.         1
# 51240      540646     84251G     GREETING CARD, OVERCROWDED POOL.         2
# 51366      540646      22165  DIAMANTE HEART SHAPED WALL MIRROR,          1
# 51512      540646      22819            BIRTHDAY CARD, RETRO SPOT         5
# 51551      540646     79030G                 TUMBLER, NEW ENGLAND         1
# 51829      540681      22819            BIRTHDAY CARD, RETRO SPOT         3
# 51891      540681      21112        SWISS ROLL TOWEL, PINK  SPOTS         4
# 51904      540681      21506           FANCY FONT BIRTHDAY CARD,          1
# 51938      540681      21900                       KEY FOB , SHED         1
# 51973      540681      22245         HOOK, 1 HANGER ,MAGIC GARDEN         1
# 51996      540681     47310M           SMALL POP BOX,FUNKY MONKEY         1
# 52008      540681     82613B       METAL SIGN,CUPCAKE SINGLE HOOK         6
# 52009      540681     82613C       METAL SIGN,CUPCAKE SINGLE HOOK         6
# 52017      540681     84251C          GREETING CARD, TWO SISTERS.         1
# 52018      540681     84251G     GREETING CARD, OVERCROWDED POOL.         1
# 52280      540700      22245         HOOK, 1 HANGER ,MAGIC GARDEN        12
# 52291      540702     85159A          BLACK TEA,COFFEE,SUGAR JARS        12
# 52311      540703      22985         WRAP, BILLBOARD FONTS DESIGN        25
# 52371      540770     79302M               ART LIGHTS,FUNK MONKEY         6
# 52646      540809      21900                       KEY FOB , SHED        24
# 52647      540809      21899              KEY FOB , GARAGE DESIGN        24
# 52648      540809      21902               KEY FOB , FRONT  DOOR         24
# 52649      540809      21901                 KEY FOB , BACK DOOR         24
# 52794      540821      22245         HOOK, 1 HANGER ,MAGIC GARDEN         1
# ...
# 508043    26-Nov-17        1.63      14096.0        United Kingdom
# 508044    26-Nov-17        1.63      14096.0        United Kingdom
# 508278    26-Nov-17        0.42      14096.0        United Kingdom
# 508386    26-Nov-17        0.83      14096.0        United Kingdom
# 508387    26-Nov-17        0.83      14096.0        United Kingdom
# 508388    26-Nov-17        0.83      14096.0        United Kingdom
# 508397    26-Nov-17        1.63      14096.0        United Kingdom
# 508747    27-Nov-17        0.42      14321.0        United Kingdom
# 508899    27-Nov-17        4.95      13883.0        United Kingdom
# 509157    27-Nov-17       10.79          NaN        United Kingdom
# 541343     7-Dec-17       10.79          NaN        United Kingdom
# 541549     7-Dec-17        3.95      12985.0        United Kingdom
# 541614     7-Dec-17        1.25      14422.0        United Kingdom
# 541787     7-Dec-17        0.42      12713.0               Germany

# %% [markdown]
# **É importante resaltar o que já até aqui para mim ficou evidente, primeiro, quando um item é cancelado a fatura tem a letra C e
# quantity é negativo. Segundo, e mais interressante, na coluna 'description' cada linha tem único pedido, mesmo quando há virgulas, é
# uma descrição a mais, portanto, na coluna unit_price aquele preço se relaciona ao pedido descrito pela coluna 'description'.**

# %%
#df3['gross_revenue'] = df3['quantity'].apply(lambda x: df3.loc[:,'quantity'] * df3.loc[:,'unit_price'] if x > 0 else 0)
# Observe que se produto retorna de algum lugar claro que tem um custo, mas não tenho informação para estimar,
#por isso ele é zero!

df3['gross_revenue'] = np.where(df3['quantity'] > 0, df3['quantity'] * df3['unit_price'], 0)

#df3['gross_revenue'] = np.where(df3['gross_revenue'] == 0, df3['quantity'] * df3['unit_price'] ) adicionar o valor do gasto ao pacote
#cancelado
# Out:
# /tmp/ipykernel_53900/2654996688.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['gross_revenue'] = np.where(df3['quantity'] > 0, df3['quantity'] * df3['unit_price'], 0)

# %% [markdown]
# **Conjunto New Features**

# %%
# Cojunto New Features
purchases = df3[df3['quantity'] > 0]
#Monetary
df_monetary = purchases.loc[:, ['customer_id', 'gross_revenue']].groupby('customer_id').sum().reset_index()
df_monetary
# Out:
#       customer_id  gross_revenue
# 0         12346.0       77183.60
# 1         12347.0        4310.00
# 2         12348.0        1797.24
# 3         12349.0        1757.55
# 4         12350.0         334.40
# ...           ...            ...
# 4334      18280.0         180.60
# 4335      18281.0          80.82
# 4336      18282.0         178.05
# 4337      18283.0        2094.88
# 4338      18287.0        1837.28
#
# [4339 rows x 2 columns]

# %%
df_ref = pd.merge(df_ref, df_monetary, on='customer_id', how='left')
df_ref
# Out:
#       customer_id  gross_revenue
# 0         17850.0        5391.21
# 1         13047.0        3237.54
# 2         12583.0        7281.38
# 3         13748.0         948.25
# 4         15100.0         876.00
# ...           ...            ...
# 4367      13436.0         196.89
# 4368      15520.0         343.50
# 4369      13298.0         360.00
# 4370      14569.0         227.39
# 4371      12713.0         848.55
#
# [4372 rows x 2 columns]

# %% [markdown]
# ### 4.1.3 Returned

# %%
df3['returned'] = np.where(df3['quantity'] < 0, 1, 0)
# Out:
# /tmp/ipykernel_53900/471871448.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['returned'] = np.where(df3['quantity'] < 0, 1, 0)

# %%
df3.head()
# Out:
#   invoice_no stock_code  quantity invoice_date  unit_price  customer_id  \
# 0     536365     85123A         6   2016-11-29        2.55      17850.0
# 1     536365      71053         6   2016-11-29        3.39      17850.0
# 2     536365     84406B         8   2016-11-29        2.75      17850.0
# 3     536365     84029G         6   2016-11-29        3.39      17850.0
# 4     536365     84029E         6   2016-11-29        3.39      17850.0
#
#           country  year  month  month_sin  month_cos  gross_revenue  returned
# 0  United Kingdom  2016     11       -0.5   0.866025          15.30         0
# 1  United Kingdom  2016     11       -0.5   0.866025          20.34         0
# 2  United Kingdom  2016     11       -0.5   0.866025          22.00         0
# 3  United Kingdom  2016     11       -0.5   0.866025          20.34         0
# 4  United Kingdom  2016     11       -0.5   0.866025          20.34         0

# %% [markdown]
# ### 4.1.4 Recency - Days from last purchase

# %%
 df3.invoice_date.max()
# Out:
# Timestamp('2017-12-07 00:00:00')

# %% [markdown]
# #O calculo será feito com referência a linha temporal dentro do dataset
#  Para calcular a diferença em dias entre uma data em seu conjunto de dados e a data atual, você pode seguir estes passos:
#
#
# import pandas as pd
# from datetime import datetime
#
# #Defina a data presente
# data_atual = pd.Timestamp.now()
#
# #Data do conjunto de dados
# data_do_dataset = pd.Timestamp('2017-12-07 00:00:00')
#
# #Calcular a diferença em dias
# diferenca_em_dias = (data_atual - data_do_dataset).days
#
# print(f'A diferença em dias entre {data_do_dataset} e a data de hoje é de {diferenca_em_dias} dias.')

# %%
aux = df_recency = df3.loc[:,['customer_id', 'invoice_date']].groupby('customer_id').max().reset_index() # pegando data mais recente 
#de cada cliente, que também em linha temporal é 

df3['recency_days'] = (df3.invoice_date.max() - aux.invoice_date).dt.days
# Out:
# /tmp/ipykernel_53900/2077048300.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['recency_days'] = (df3.invoice_date.max()- df3.invoice_date).dt.days

# %% [markdown]
# **Conjunto New Features**

# %%
# Conjunto New Features
filtro =  df3[df3['quantity'] > 0]
df_recency = filtro.loc[:,['customer_id', 'invoice_date']].groupby('customer_id').max().reset_index() # pegando a maior data de cada cliente, que também em linha temporal é 
# mais recente
df_recency['recency_days'] =  (df3.invoice_date.max() - df_recency.invoice_date).dt.days
df_recency
# Out:
#       customer_id invoice_date  recency_days
# 0         12346.0   2017-01-16           325
# 1         12347.0   2017-12-05             2
# 2         12348.0   2017-09-23            75
# 3         12349.0   2017-11-19            18
# 4         12350.0   2017-01-31           310
# ...           ...          ...           ...
# 4334      18280.0   2017-03-05           277
# 4335      18281.0   2017-06-10           180
# 4336      18282.0   2017-11-30             7
# 4337      18283.0   2017-12-04             3
# 4338      18287.0   2017-10-26            42
#
# [4339 rows x 3 columns]

# %%
df_recency = df_recency[['customer_id', 'recency_days']].copy()
df_ref = pd.merge(df_ref, df_recency, on='customer_id', how='left')
df_ref
# Out:
#       customer_id  gross_revenue  recency_days
# 0         17850.0        5391.21         372.0
# 1         13047.0        3237.54          31.0
# 2         12583.0        7281.38           2.0
# 3         13748.0         948.25          95.0
# 4         15100.0         876.00         333.0
# ...           ...            ...           ...
# 4367      13436.0         196.89           1.0
# 4368      15520.0         343.50           1.0
# 4369      13298.0         360.00           1.0
# 4370      14569.0         227.39           1.0
# 4371      12713.0         848.55           0.0
#
# [4372 rows x 3 columns]

# %% [markdown]
# ### 4.1.5 Quantity purchased

# %%
df3.shape
# Out:
# (406829, 14)

# %%
# Quantidade de vezes que o cliente realizou a compra
df_freq = filtro.loc[:, ['customer_id', 'invoice_no']].drop_duplicates().groupby('customer_id').count().reset_index().rename(columns = { 'invoice_no': 'qtde_invoices'})
df_ref = pd.merge( df_ref, df_freq, on = 'customer_id', how = 'left')
df_ref
# Out:
#       customer_id  gross_revenue  recency_days  qtde_invoices
# 0         17850.0        5391.21         372.0           34.0
# 1         13047.0        3237.54          31.0           10.0
# 2         12583.0        7281.38           2.0           15.0
# 3         13748.0         948.25          95.0            5.0
# 4         15100.0         876.00         333.0            3.0
# ...           ...            ...           ...            ...
# 4367      13436.0         196.89           1.0            1.0
# 4368      15520.0         343.50           1.0            1.0
# 4369      13298.0         360.00           1.0            1.0
# 4370      14569.0         227.39           1.0            1.0
# 4371      12713.0         848.55           0.0            1.0
#
# [4372 rows x 4 columns]

# %%
df_freq = filtro.loc[:, ['customer_id', 'invoice_no']].drop_duplicates().groupby('customer_id').count().reset_index().rename(columns={'invoice_no':'qtde_invoices'})
df_ref = pd.merge(df_ref, df_freq, on='customer_id', how='left')

# %% [markdown]
# Parece haver um erro na lógica, para calcular a quantidade de vezes que o cliente comprou e selecionando somente as colunas
# ['customer_id', 'invoice_no'], terá valores repetido, mas não significa que são duplicadas, pois está observação limitou somente a duas
# colunas que podem se repetir se mesmo cliente comprar no mesmo dia.

# %%
# experimento sem deletar o que parece ser duplicado
ux = df3.loc[:, ['customer_id', 'invoice_no']].groupby('customer_id').count().reset_index()
ux
# Out:
#       customer_id  invoice_no
# 0         12346.0           2
# 1         12347.0         182
# 2         12348.0          31
# 3         12349.0          73
# 4         12350.0          17
# 5         12352.0          95
# 6         12353.0           4
# 7         12354.0          58
# 8         12355.0          13
# 9         12356.0          59
# 10        12357.0         131
# 11        12358.0          19
# 12        12359.0         254
# 13        12360.0         129
# 14        12361.0          10
# 15        12362.0         274
# 16        12363.0          23
# 17        12364.0          85
# 18        12365.0          23
# 19        12367.0          11
# 20        12370.0         167
# 21        12371.0          63
# 22        12372.0          52
# 23        12373.0          14
# 24        12374.0          33
# 25        12375.0          18
# 26        12377.0          77
# 27        12378.0         219
# 28        12379.0          41
# 29        12380.0         105
# 30        12381.0          91
# 31        12383.0         100
# 32        12384.0          30
# 33        12386.0          10
# 34        12388.0         100
# 35        12390.0          32
# 36        12391.0         100
# 37        12393.0          64
# 38        12394.0          27
# 39        12395.0         159
# 40        12397.0         126
# 41        12398.0          85
# 42        12399.0          59
# 43        12401.0           5
# 44        12402.0          11
# 45        12403.0           6
# 46        12405.0          54
# 47        12406.0         108
# 48        12407.0          77
# 49        12408.0         113
# 50        12409.0         114
# 51        12410.0          28
# 52        12412.0          61
# 53        12413.0          40
# 54        12414.0          18
# 55        12415.0         778
# 56        12417.0         198
# 57        12418.0          34
# 58        12420.0          29
# 59        12421.0          46
# 60        12422.0          39
# 61        12423.0         126
# 62        12424.0          30
# 63        12425.0          36
# 64        12426.0          30
# 65        12427.0          35
# 66        12428.0         300
# 67        12429.0          97
# 68        12430.0          11
# 69        12431.0         240
# 70        12432.0         108
# 71        12433.0         420
# 72        12434.0          54
# 73        12435.0          36
# 74        12436.0          16
# 75        12437.0         201
# 76        12438.0          98
# 77        12441.0          11
# 78        12442.0          12
# 79        12444.0         177
# 80        12445.0           4
# 81        12446.0          58
# 82        12447.0          26
# 83        12448.0          22
# 84        12449.0         191
# 85        12450.0           8
# 86        12451.0         355
# 87        12452.0          23
969   BOX OF 6 ASSORTED COLOUR TEASPOONS         6
# 14958      537626     84997C    BLUE 3 PIECE POLKADOT CUTLERY SET         6
# 14959      537626     84997B    RED 3 PIECE RETROSPOT CUTLERY SET         6
# 14960      537626     84997D    PINK 3 PIECE POLKADOT CUTLERY SET         6
# 14961      537626      22494             EMERGENCY FIRST AID TIN         12
# 14962      537626      22497      SET OF 2 TINS VINTAGE BATHROOM          4
# 14963      537626     85232D        SET/3 DECOUPAGE STACKING TINS         3
# 14964      537626      21064                BOOM BOX SPEAKER BOYS         6
# 14965      537626      21731        RED TOADSTOOL LED NIGHT LIGHT        12
# 14966      537626     84558A         3D DOG PICTURE PLAYING CARDS        24
# 14967      537626      20780            BLACK EAR MUFF HEADPHONES        12
# 14968      537626      20782       CAMOUFLAGE EAR MUFF HEADPHONES         6
# 72246      542237     84625A   PINK NEW BAROQUECANDLESTICK CANDLE        24
# 72247      542237     84625C  BLUE NEW BAROQUE CANDLESTICK CANDLE        24
# 72248      542237      85116      BLACK CANDELABRA T-LIGHT HOLDER         6
# 72249      542237      20719               WOODLAND CHARLOTTE BAG        10
# 72250      542237      22375    AIRLINE BAG VINTAGE JET SET BROWN         4
# 72251      542237      22376    AIRLINE BAG VINTAGE JET SET WHITE         4
# 72252      542237      20966                 SANDWICH BATH SPONGE        10
# 72253      542237      22725       ALARM CLOCK BAKELIKE CHOCOLATE         4
# 72254      542237      22726           ALARM CLOCK BAKELIKE GREEN         4
# 72255      542237      22727            ALARM CLOCK BAKELIKE RED          4
# 72256      542237      22728            ALARM CLOCK BAKELIKE PINK         4
# 72257      542237      22729          ALARM CLOCK BAKELIKE ORANGE         4
# 72258      542237      22196         SMALL HEART MEASURING SPOONS        12
# 72259      542237      84992       72 SWEETHEART FAIRY CAKE CASES        24
# 72260      542237      84991          60 TEATIME FAIRY CAKE CASES        24
# 72261      542237      21976       PACK OF 60 MUSHROOM CAKE CASES        24
# 72262      542237      22417       PACK OF 60 SPACEBOY CAKE CASES        24
# 72263      542237     47559B                  TEA TIME OVEN GLOVE        10
# 72264      542237      21154            RED RETROSPOT OVEN GLOVE         10
# 72265      542237      21041      RED RETROSPOT OVEN GLOVE DOUBLE         6
# 72266      542237      21035      SET/2 RED RETROSPOT TEA TOWELS          6
# 72267      542237      22423             REGENCY CAKESTAND 3 TIER         3
# 72268      542237      84969   BOX OF 6 ASSORTED COLOUR TEASPOONS         6
# 72269      542237      22134           MINI LADLE LOVE HEART RED         12
# 72270      542237      21832                 CHOCOLATE CALCULATOR        12
# 72271      542237      22422                  TOOTHPASTE TUBE PEN        12
# 72272      542237      22497      SET OF 2 TINS VINTAGE BATHROOM          4
# 72273      542237      21731        RED TOADSTOOL LED NIGHT LIGHT        12
# 72274      542237     84558A         3D DOG PICTURE PLAYING CARDS        12
# 148285     549222      22376    AIRLINE BAG VINTAGE JET SET WHITE         4
# 148286     549222      22374      AIRLINE BAG VINTAGE JET SET RED         4
# 148287     549222      22371         AIRLINE BAG VINTAGE TOKYO 78         4
# 148288     549222      22375    AIRLINE BAG VINTAGE JET SET BROWN         4
# 148289     549222      20665                 RED RETROSPOT PURSE          6
# 148290     549222      23076           ICE CREAM SUNDAE LIP GLOSS       240
# 148291     549222      21791   VINTAGE HEADS AND TAILS CARD GAME         12
# 148292     549222      22550                     HOLIDAY FUN LUDO         8
# 148293     549222      23177             TREASURE ISLAND BOOK BOX         8
# 148294     549222      22432              WATERING CAN PINK BUNNY         6
# 148295     549222      22774    RED DRAWER KNOB ACRYLIC EDWARDIAN        12
# 148296     549222      22195         LARGE HEART MEASURING SPOONS        12
# 148297     549222      22196         SMALL HEART MEASURING SPOONS        12
# 148298     549222      21975       PACK OF 60 DINOSAUR CAKE CASES        24
# 148299     549222      21041      RED RETROSPOT OVEN GLOVE DOUBLE         6
# 148300     549222      22423             REGENCY CAKESTAND 3 TIER         3
# 148301     549222      22699     ROSES REGENCY TEACUP AND SAUCER          6
# 148302     549222      21731        RED TOADSTOOL LED NIGHT LIGHT        12
# 148303     549222      22492              MINI PAINT SET VINTAGE         36
# 148304     549222     84559A             3D SHEET OF DOG STICKERS        12
# 148305     549222     84559B             3D SHEET OF CAT STICKERS        12
# 148306     549222      16008  SMALL FOLDING SCISSOR(POINTED EDGE)        24
# 148307     549222      22821          GIFT BAG PSYCHEDELIC APPLES        12
# 148308     549222      22497      SET OF 2 TINS VINTAGE BATHROOM          4
# 220572     556201      23084                   RABBIT NIGHT LIGHT        12
# 220573     556201      23162                 REGENCY TEA STRAINER         8
# 220574     556201      23171             REGENCY TEA PLATE GREEN         12
# 220575     556201      23172               REGENCY TEA PLATE PINK        12
# 220576     556201      23170             REGENCY TEA PLATE ROSES         12
# 220577     556201      23173                REGENCY TEAPOT ROSES          2
# 220578     556201      23174             REGENCY SUGAR BOWL GREEN         4
# 220579     556201      23175               REGENCY MILK JUG PINK          4
# 220580     556201      22371         AIRLINE BAG VINTAGE TOKYO 78         8
# 220581     556201      22375    AIRLINE BAG VINTAGE JET SET BROWN         4
# 220582     556201      85178                 VICTORIAN SEWING KIT        12
# 220583     556201      17021               NAMASTE SWAGAT INCENSE        36
# 220584     556201      23146       TRIPLE HOOK ANTIQUE IVORY ROSE         4
# 220585     556201      22196         SMALL HEART MEASURING SPOONS        24
# 220586     556201     84558A         3D DOG PICTURE PLAYING CARDS        18
# 220587     556201     51014C               FEATHER PEN,COAL BLACK        12
# 220588     556201      22727            ALARM CLOCK BAKELIKE RED          8
# 220589     556201      22725       ALARM CLOCK BAKELIKE CHOCOLATE         4
# 286621     562032      23308   SET OF 60 VINTAGE LEAF CAKE CASES         24
# 286622     562032      23297  SET 40 HEART SHAPE PETIT FOUR CASES        16
# 286623     562032      22375    AIRLINE BAG VINTAGE JET SET BROWN         4
# 286624     562032      22374      AIRLINE BAG VINTAGE JET SET RED         4
# 286625     562032      22376    AIRLINE BAG VINTAGE JET SET WHITE         4
# 286626     562032      22371         AIRLINE BAG VINTAGE TOKYO 78         8
# 286627     562032      22372  AIRLINE BAG VINTAGE WORLD CHAMPION          4
# 286628     562032      21578     WOODLAND DESIGN  COTTON TOTE BAG         6
# 286629     562032      20719               WOODLAND CHARLOTTE BAG        10
# 286630     562032      22727            ALARM CLOCK BAKELIKE RED          8
# 286631     562032      23146       TRIPLE HOOK ANTIQUE IVORY ROSE         4
# 286632     562032      23147       SINGLE ANTIQUE ROSE HOOK IVORY        12
# 286633     562032     47559B                  TEA TIME OVEN GLOVE        10
# 286634     562032      84992       72 SWEETHEART FAIRY CAKE CASES        24
# 286635     562032      84991          60 TEATIME FAIRY CAKE CASES        24
# 286636     562032      21975       PACK OF 60 DINOSAUR CAKE CASES        24
# 286637     562032      22423             REGENCY CAKESTAND 3 TIER         3
# 286638     562032      23175               REGENCY MILK JUG PINK          4
# 286639     562032     84558A         3D DOG PICTURE PLAYING CARDS        36
# 286640     562032      22992               REVOLVER WOODEN RULER         12
# 286641     562032      21791   VINTAGE HEADS AND TAILS CARD GAME         24
# 286642     562032      23316                 RED REFECTORY CLOCK         12
# 428957     573511      23480       MINI LIGHTS WOODLAND MUSHROOMS        12
# 428958     573511      21265         PINK GOOSE FEATHER TREE 60CM        12
# 428959     573511      21636               MADRAS NOTEBOOK MEDIUM        12
# 428960     573511      22372  AIRLINE BAG VINTAGE WORLD CHAMPION          4
# 428961     573511      22375    AIRLINE BAG VINTAGE JET SET BROWN         8
# 428962     573511      22371         AIRLINE BAG VINTAGE TOKYO 78        12
# 428963     573511      22374      AIRLINE BAG VINTAGE JET SET RED         8
# 428964     573511      22252  BIRDCAGE DECORATION TEALIGHT HOLDER        12
# 428965     573511      22945       CHRISTMAS METAL TAGS ASSORTED         12
# 428966     573511      22423             REGENCY CAKESTAND 3 TIER         6
# 428967     573511      23173                REGENCY TEAPOT ROSES          2
# 428968     573511      47580                TEA TIME DES TEA COSY         6
# 428969     573511     47567B               TEA TIME KITCHEN APRON         6
# 428970     573511     47559B                  TEA TIME OVEN GLOVE        10
# 428971     573511      22698       PINK REGENCY TEACUP AND SAUCER        12
# 428972     573511      22697      GREEN REGENCY TEACUP AND SAUCER        12
# 428973     573511     84558A         3D DOG PICTURE PLAYING CARDS        36
# 428974     573511      23084                   RABBIT NIGHT LIGHT        48
# 428975     573511      21731        RED TOADSTOOL LED NIGHT LIGHT        12
# 428976     573511      23177             TREASURE ISLAND BOOK BOX         8
# 428977     573511      21791   VINTAGE HEADS AND TAILS CARD GAME         12
# 428978     573511      23508       MINI PLAYING CARDS DOLLY GIRL         20
# 428979     573511      23506         MINI PLAYING CARDS SPACEBOY         20
# 428980     573511      23503   PLAYING CARDS KEEP CALM & CARRY ON        12
# 428981     573511      22992               REVOLVER WOODEN RULER         12
# 428982     573511      22561          WOODEN SCHOOL COLOURING SET        12
# 428983     573511      22492              MINI PAINT SET VINTAGE         36
# 428984     573511      22621           TRADITIONAL KNITTING NANCY        12
# 428985     573511      23146       TRIPLE HOOK ANTIQUE IVORY ROSE         8
# 428986     573511      23421                  PANTRY HOOK SPATULA        12
# 428987     573511      23422           PANTRY HOOK BALLOON WHISK         12
# 428988     573511      23420            PANTRY HOOK TEA STRAINER         12
# 428989     573511      22699     ROSES REGENCY TEACUP AND SAUCER         18
# 428990     573511      22725       ALARM CLOCK BAKELIKE CHOCOLATE         8
# 428991     573511      22728            ALARM CLOCK BAKELIKE PINK         8
# 428992     573511      22726           ALARM CLOCK BAKELIKE GREEN         8
# 428993     573511      22727            ALARM CLOCK BAKELIKE RED         12
# 428994     573511      21976       PACK OF 60 MUSHROOM CAKE CASES        24
# 428978    29-Oct-17        0.42      12347.0  Iceland
# 428979    29-Oct-17        0.42      12347.0  Iceland
# 428980    29-Oct-17        1.25      12347.0  Iceland
# 428981    29-Oct-17        1.95      12347.0  Iceland
# 428982    29-Oct-17        1.65      12347.0  Iceland
# 428983    29-Oct-17        0.65      12347.0  Iceland
# 428984    29-Oct-17        1.65      12347.0  Iceland
# 428985    29-Oct-17        3.29      12347.0  Iceland
# 428986    29-Oct-17        2.08      12347.0  Iceland
# 428987    29-Oct-17        2.08      12347.0  Iceland
# 428988    29-Oct-17        2.08      12347.0  Iceland
# 428989    29-Oct-17        2.95      12347.0  Iceland
# 428990    29-Oct-17        3.75      12347.0  Iceland
# 428991    29-Oct-17        3.75      12347.0  Iceland
# 428992    29-Oct-17        3.75      12347.0  Iceland
# 428993    29-Oct-17        3.75      12347.0  Iceland
# 428994    29-Oct-17        0.55      12347.0  Iceland
# 428995    29-Oct-17        0.55      12347.0  Iceland
# 428996    29-Oct-17        0.55      12347.0  Iceland
# 428997    29-Oct-17        0.55      12347.0  Iceland
# 428998    29-Oct-17        0.55      12347.0  Iceland
# 428999    29-Oct-17        0.85      12347.0  Iceland
# 429000    29-Oct-17        1.65      12347.0  Iceland
# 429001    29-Oct-17        0.85      12347.0  Iceland
# 429002    29-Oct-17        3.75      12347.0  Iceland
# 429003    29-Oct-17        1.95      12347.0  Iceland
# 535004     5-Dec-17        1.45      12347.0  Iceland
# 535005     5-Dec-17        2.08      12347.0  Iceland
# 535006     5-Dec-17        1.25      12347.0  Iceland
# 535007     5-Dec-17        0.85      12347.0  Iceland
# 535008     5-Dec-17        1.65      12347.0  Iceland
# 535009     5-Dec-17        1.79      12347.0  Iceland
# 535010     5-Dec-17        0.85      12347.0  Iceland
# 535011     5-Dec-17        1.95      12347.0  Iceland
# 535012     5-Dec-17        0.83      12347.0  Iceland
# 535013     5-Dec-17        0.42      12347.0  Iceland
# 535014     5-Dec-17        0.42      12347.0  Iceland

# %% [markdown]
# Observe que as colunas 'invoice_no' e 'customer_id' as vezes se repete em compras do mesmo dia, mais o produto é outro, informação que está
# nas outras colunas que outrora foi deixado de lado

# %%
p.shape
# Out:
# (182, 8)

# %%
# CORRIGIDO...

df_freq = filtro.loc[:, ['customer_id', 'invoice_no']].drop_duplicates().groupby('customer_id').count().reset_index().rename(columns={'invoice_no':'qtde_invoices'})
df_ref = pd.merge(df_ref, df_freq, on='customer_id', how='left')


# Composição geral


aux = df3
# df.drop_duplicates(subset=['coluna1', 'coluna2']) remover linhas duplicadas de um determinada coluna

aux = df3.loc[:, ['customer_id', 'invoice_no']].groupby('customer_id').count().reset_index()
 

# Supondo que você tenha um DataFrame df com uma coluna chamada "old_column_name"
# Renomear a coluna "old_column_name" para "new_column_name"
#df.rename(columns={'old_column_name': 'new_column_name'}, inplace=True)
aux.rename(columns={'invoice_no': 'n_invoice'}, inplace=True)


aux.head()
# Out:
#    customer_id  n_invoice
# 0      12346.0          2
# 1      12347.0          7
# 2      12348.0          4
# 3      12349.0          1
# 4      12350.0          1

# %%
# Supondo que df1 e df2 sejam seus dataframes
# Use a função merge para juntar os dataframes, baseando-se na coluna 'customer_id'
df3 = df3.merge(aux[['customer_id', 'n_invoice']], on='customer_id', how='left')

df3.head()
# Out:
#   invoice_no stock_code  quantity invoice_date  unit_price  customer_id  \
# 0     536365     85123A         6   2016-11-29        2.55      17850.0
# 1     536365      71053         6   2016-11-29        3.39      17850.0
# 2     536365     84406B         8   2016-11-29        2.75      17850.0
# 3     536365     84029G         6   2016-11-29        3.39      17850.0
# 4     536365     84029E         6   2016-11-29        3.39      17850.0
#
#           country  year  month  month_sin  month_cos  gross_revenue  returned  \
# 0  United Kingdom  2016     11       -0.5   0.866025          15.30         0
# 1  United Kingdom  2016     11       -0.5   0.866025          20.34         0
# 2  United Kingdom  2016     11       -0.5   0.866025          22.00         0
# 3  United Kingdom  2016     11       -0.5   0.866025          20.34         0
# 4  United Kingdom  2016     11       -0.5   0.866025          20.34         0
#
#    recency_days  n_invoice
# 0           373         35
# 1           373         35
# 2           373         35
# 3           373         35
# 4           373         35

# %% [markdown]
# ### 4.1.6 Quantity total of items purchased

# %%
#quantidade de items comprados durante todo esse tempo 
# em relação ao original qtde_items se tornou total_items, para ficar mais claro total de items comprado pelo cliente.
df_freq = filtro.loc[:, ['customer_id', 'quantity']].groupby('customer_id').sum().reset_index().rename(columns={'quantity':'total_items'})
df_ref = pd.merge(df_ref, df_freq, on='customer_id', how='left')
df_freq.head(3)
# Out:
#    customer_id  qtde_items
# 0      12346.0       74215
# 1      12347.0        2458
# 2      12348.0        2341

# %%
aux = df3.loc[:, ['customer_id', 'quantity']].groupby('customer_id').sum().reset_index().rename(columns={'quantity':'total_items'})

df3 = df3.merge(aux[['customer_id', 'total_items']], on='customer_id', how='left')

# %% [markdown]
# ### 4.1.7 Quantity of products purchased

# %%
df_freq = filtro.loc[:, ['customer_id', 'stock_code']].groupby('customer_id').count().reset_index().rename(columns={'stock_code':'qtde_products'})
df_ref = pd.merge(df_ref, df_freq, on='customer_id', how='left')
df_ref.head()
# Out:
#    customer_id  gross_revenue  recency_days  qtde_invoices_x  qtde_invoices_y  \
# 0      17850.0        5391.21         372.0             34.0             34.0
# 1      13047.0        3237.54          31.0             10.0             10.0
# 2      12583.0        7281.38           2.0             15.0             15.0
# 3      13748.0         948.25          95.0              5.0              5.0
# 4      15100.0         876.00         333.0              3.0              3.0
#
#    qtde_items  qtde_products
# 0      1733.0          297.0
# 1      1391.0          172.0
# 2      5060.0          247.0
# 3       439.0           28.0
# 4        80.0            3.0

# %%
aux = df3.loc[:, ['customer_id', 'stock_code']].groupby('customer_id').count().reset_index().rename(columns={'stock_code':'qtde_products'})
df3 = df3.merge(aux[['customer_id', 'qtde_products']], on='customer_id', how='left')
df3.head()
# Out:
#   invoice_no stock_code  quantity invoice_date  unit_price  customer_id  \
# 0     536365     85123A         6   2016-11-29        2.55      17850.0
# 1     536365      71053         6   2016-11-29        3.39      17850.0
# 2     536365     84406B         8   2016-11-29        2.75      17850.0
# 3     536365     84029G         6   2016-11-29        3.39      17850.0
# 4     536365     84029E         6   2016-11-29        3.39      17850.0
#
#           country  year  month  month_sin  month_cos  gross_revenue  returned  \
# 0  United Kingdom  2016     11       -0.5   0.866025          15.30         0
# 1  United Kingdom  2016     11       -0.5   0.866025          20.34         0
# 2  United Kingdom  2016     11       -0.5   0.866025          22.00         0
# 3  United Kingdom  2016     11       -0.5   0.866025          20.34         0
# 4  United Kingdom  2016     11       -0.5   0.866025          20.34         0
#
#    recency_days  n_invoice  qtde_items  qtde_products
# 0           373         35        1693            312
# 1           373         35        1693            312
# 2           373         35        1693            312
# 3           373         35        1693            312
# 4           373         35        1693            312

# %% [markdown]
# ### 4.1.8 Average Ticket Valuem

# %%
# average ticket
df_avg_ticket = filtro.loc[:, ['customer_id', 'gross_revenue']].groupby('customer_id').mean().reset_index().rename(columns={'gross_revenue':'avg_ticket'})
df_ref = pd.merge(df_ref, df_avg_ticket, on='customer_id', how='left')

# %%
aux = df3.loc[:, ['customer_id', 'gross_revenue']].groupby('customer_id').mean().reset_index().rename(columns={'gross_revenue':'avg_ticket'})
df3 = df3.merge(aux[['customer_id', 'avg_ticket']], on='customer_id', how='left')
df3.head()
# Out:
#   invoice_no stock_code  quantity invoice_date  unit_price  customer_id  \
# 0     536365     85123A         6   2016-11-29        2.55      17850.0
# 1     536365      71053         6   2016-11-29        3.39      17850.0
# 2     536365     84406B         8   2016-11-29        2.75      17850.0
# 3     536365     84029G         6   2016-11-29        3.39      17850.0
# 4     536365     84029E         6   2016-11-29        3.39      17850.0
#
#           country  year  month  month_sin  month_cos  gross_revenue  returned  \
# 0  United Kingdom  2016     11       -0.5   0.866025          15.30         0
# 1  United Kingdom  2016     11       -0.5   0.866025          20.34         0
# 2  United Kingdom  2016     11       -0.5   0.866025          22.00         0
# 3  United Kingdom  2016     11       -0.5   0.866025          20.34         0
# 4  United Kingdom  2016     11       -0.5   0.866025          20.34         0
#
#    recency_days  n_invoice  qtde_items  qtde_products  avg_ticket
# 0           373         35        1693            312   17.279519
# 1           373         35        1693            312   17.279519
# 2           373         35        1693            312   17.279519
# 3           373         35        1693            312   17.279519
# 4           373         35        1693            312   17.279519

# %%
df3.isnull().sum()
# Out:
# invoice_no       0
# stock_code       0
# quantity         0
# invoice_date     0
# unit_price       0
# customer_id      0
# country          0
# year             0
# month            0
# month_sin        0
# month_cos        0
# gross_revenue    0
# returned         0
# recency_days     0
# n_invoice        0
# qtde_items       0
# qtde_products    0
# avg_ticket       0
# dtype: int64

# %%
df_ref.isnull().sum()
# Out:
# customer_id         0
# gross_revenue      33
# recency_days       33
# qtde_invoices_x    33
# qtde_invoices_y    33
# qtde_items         33
# qtde_products      33
# avg_ticket         33
# dtype: int64

# %%
#df3.drop(columns = 'avg_ticket_x', axis = 1, inplace = True)

# %%
#df3.rename(columns ={ 'avg_ticket_y': 'avg_ticket'}, inplace = True )

# %% [markdown]
# ### 4.1.9 Frequency Purchase

# %%
df_aux = ( filtro[['invoice_no', 'customer_id', 'invoice_date']].drop_duplicates()
                                                  .groupby('customer_id')
                                                  .agg(max_ = ('invoice_date', 'max'),
                                                      min_ = ('invoice_date', 'min'),
                                                      days_ = ('invoice_date', lambda x: ((x.max() - x.min()).days) + 0),
                                                      buys_ = ('invoice_no', 'count')) ).reset_index()


df_aux.head()
# Out:
#    customer_id       max_       min_  days_  buys_
# 0      12346.0 2017-01-16 2017-01-16      0      1
# 1      12347.0 2017-12-05 2016-12-05    365      7
# 2      12348.0 2017-09-23 2016-12-14    283      4
# 3      12349.0 2017-11-19 2017-11-19      0      1
# 4      12350.0 2017-01-31 2017-01-31      0      1

# %%
aux = ( df3[['invoice_no', 'customer_id', 'invoice_date']].drop_duplicates()
                                                  .groupby('customer_id')
                                                  .agg(max_ = ('invoice_date', 'max'),
                                                      min_ = ('invoice_date', 'min'),
                                                      days_ = ('invoice_date', lambda x: ((x.max() - x.min()).days) + 0),
                                                      buys_ = ('invoice_no', 'count')) ).reset_index()


aux.head()
# Out:
#    customer_id       max_       min_  days_  buys_
# 0      12346.0 2017-01-16 2017-01-16      0      2
# 1      12347.0 2017-12-05 2016-12-05    365      7
# 2      12348.0 2017-09-23 2016-12-14    283      4
# 3      12349.0 2017-11-19 2017-11-19      0      1
# 4      12350.0 2017-01-31 2017-01-31      0      1

# %%
#Frequency
df_aux['frequency'] = df_aux[['buys_', 'days_']].apply(lambda x: x['buys_'] / x['days_'] if x['days_'] !=0 else 0, axis=1)
df_ref = pd.merge(df_ref, df_aux[['customer_id', 'frequency']], on='customer_id', how='left')
df_ref.head()
# Out:
#    customer_id  gross_revenue  recency_days  qtde_invoices_x  qtde_invoices_y  \
# 0      17850.0        5391.21         372.0             34.0             34.0
# 1      13047.0        3237.54          31.0             10.0             10.0
# 2      12583.0        7281.38           2.0             15.0             15.0
# 3      13748.0         948.25          95.0              5.0              5.0
# 4      15100.0         876.00         333.0              3.0              3.0
#
#    qtde_items  qtde_products  avg_ticket  frequency
# 0      1733.0          297.0   18.152222  34.000000
# 1      1391.0          172.0   18.822907   0.029240
# 2      5060.0          247.0   29.479271   0.040431
# 3       439.0           28.0   33.866071   0.017986
# 4        80.0            3.0  292.000000   0.075000

# %%
df_ref.dtypes
# Out:
# customer_id        float64
# gross_revenue      float64
# recency_days       float64
# qtde_invoices_x    float64
# qtde_invoices_y    float64
# qtde_items         float64
# qtde_products      float64
# avg_ticket         float64
# frequency          float64
# dtype: object

# %%
df_ref[df_ref['customer_id'] == 12346.0]
# Out:
#       customer_id  gross_revenue  recency_days  qtde_invoices_x  \
# 1169      12346.0        77183.6         325.0              1.0
#
#       qtde_invoices_y  qtde_items  qtde_products  avg_ticket  frequency
# 1169              1.0     74215.0            1.0     77183.6        0.0

# %%
#Frequency
aux['frequency'] = aux[['buys_', 'days_']].apply(lambda x: x['buys_'] / x['days_'] if x['days_'] !=0 else 0, axis=1)
df3 = pd.merge(df3, aux[['customer_id', 'frequency']], on='customer_id', how='left')
df3.head()
# Out:
#   invoice_no stock_code  quantity invoice_date  unit_price  customer_id  \
# 0     536365     85123A         6   2016-11-29        2.55      17850.0
# 1     536365      71053         6   2016-11-29        3.39      17850.0
# 2     536365     84406B         8   2016-11-29        2.75      17850.0
# 3     536365     84029G         6   2016-11-29        3.39      17850.0
# 4     536365     84029E         6   2016-11-29        3.39      17850.0
#
#           country  year  month  month_sin  month_cos  gross_revenue  returned  \
# 0  United Kingdom  2016     11       -0.5   0.866025          15.30         0
# 1  United Kingdom  2016     11       -0.5   0.866025          20.34         0
# 2  United Kingdom  2016     11       -0.5   0.866025          22.00         0
# 3  United Kingdom  2016     11       -0.5   0.866025          20.34         0
# 4  United Kingdom  2016     11       -0.5   0.866025          20.34         0
#
#    recency_days  n_invoice  qtde_items  qtde_products  avg_ticket  frequency
# 0           373         35        1693            312   17.279519   0.486111
# 1           373         35        1693            312   17.279519   0.486111
# 2           373         35        1693            312   17.279519   0.486111
# 3           373         35        1693            312   17.279519   0.486111
# 4           373         35        1693            312   17.279519   0.486111

# %%
df3.isnull().sum()
# Out:
# invoice_no       0
# stock_code       0
# quantity         0
# invoice_date     0
# unit_price       0
# customer_id      0
# country          0
# year             0
# month            0
# month_sin        0
# month_cos        0
# gross_revenue    0
# returned         0
# recency_days     0
# n_invoice        0
# qtde_items       0
# qtde_products    0
# avg_ticket       0
# frequency        0
# dtype: int64

# %% [markdown]
# ### 4.1.10 Number of Returns

# %%
df_returns = cancelled[['customer_id', 'quantity']].groupby('customer_id').sum().reset_index().rename(columns={'quantity':'qtde_returns'})
df_returns['qtde_returns'] = df_returns['qtde_returns'] * -1
df_ref = pd.merge(df_ref, df_returns, on='customer_id', how='left')
df_ref.loc[df_ref['qtde_returns'].isna(), 'qtde_returns'] = 0

# %%
test = df3[df3['returned'] == 1]
test =test.head()

# %%
aux = df3.loc[df3['returned'] == 1, ['customer_id', 'returned']].groupby('customer_id').sum().reset_index().rename( columns = {'returned': 'n_returned'})
aux.head()
# Out:
#    customer_id  n_returned
# 0      12346.0           1
# 1      12352.0          10
# 2      12359.0           6
# 3      12362.0           8
# 4      12365.0           1

# %%
df3 = pd.merge(df3, aux, on='customer_id', how='left')

# %%
df3.isnull().sum()
# Out:
# invoice_no       0
# stock_code       0
# quantity         0
# invoice_date     0
# unit_price       0
# customer_id      0
# country          0
# year             0
# month            0
# month_sin        0
# month_cos        0
# gross_revenue    0
# returned         0
# recency_days     0
# n_invoice        0
# qtde_items       0
# qtde_products    0
# avg_ticket       0
# frequency        0
# n_returned       0
# dtype: int64

# %%
df3['n_returned'] = df3['n_returned'].apply(lambda x: 0 if x == 'nan' or 'Nan' or 'NAN' or 'NaN' else x)

# %% [markdown]
# ### 4.1.11 Basket Size - Quantidade de items por cesta (Quantity)

# %%
df_aux = ( filtro.loc[:, ['customer_id', 'invoice_no', 'quantity']].groupby('customer_id')
                                                                          .agg(n_purchase = ('invoice_no', 'nunique'),
                                                                               n_products = ('quantity', 'sum')).reset_index() )

df_aux['avg_basket_size'] = df_aux['n_products'] / df_aux['n_purchase']
df_ref = pd.merge(df_ref, df_aux[['customer_id', 'avg_basket_size']], on='customer_id', how='left')

# %%
aux = ( df3.loc[:, ['customer_id', 'invoice_no', 'quantity']].groupby('customer_id')
                                                                          .agg(n_purchase = ('invoice_no', 'nunique'),
                                                                               n_products = ('quantity', 'sum')).reset_index() )
aux
aux['avg_basket_size'] = aux['n_products'] /  aux['n_purchase']
df3 = pd.merge(df3, aux[['customer_id', 'avg_basket_size']], on='customer_id', how='left')

# %%
df3.head()
# Out:
#   invoice_no stock_code  quantity invoice_date  unit_price  customer_id  \
# 0     536365     85123A         6   2016-11-29        2.55      17850.0
# 1     536365      71053         6   2016-11-29        3.39      17850.0
# 2     536365     84406B         8   2016-11-29        2.75      17850.0
# 3     536365     84029G         6   2016-11-29        3.39      17850.0
# 4     536365     84029E         6   2016-11-29        3.39      17850.0
#
#           country  year  month  month_sin  ...  gross_revenue  returned  \
# 0  United Kingdom  2016     11       -0.5  ...          15.30         0
# 1  United Kingdom  2016     11       -0.5  ...          20.34         0
# 2  United Kingdom  2016     11       -0.5  ...          22.00         0
# 3  United Kingdom  2016     11       -0.5  ...          20.34         0
# 4  United Kingdom  2016     11       -0.5  ...          20.34         0
#
#    recency_days  n_invoice  qtde_items  qtde_products  avg_ticket  frequency  \
# 0           373         35        1693            312   17.279519   0.486111
# 1           373         35        1693            312   17.279519   0.486111
# 2           373         35        1693            312   17.279519   0.486111
# 3           373         35        1693            312   17.279519   0.486111
# 4           373         35        1693            312   17.279519   0.486111
#
#    n_returned  avg_basket_size
# 0           0        48.371429
# 1           0        48.371429
# 2           0        48.371429
# 3           0        48.371429
# 4           0        48.371429
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 4.1.12 Unique Basket Size - Quantidade de Itens por Cesta (Stock_code)

# %%
df_aux = ( filtro.loc[:, ['customer_id', 'invoice_no', 'stock_code']].groupby('customer_id')
                                                                          .agg(n_purchase = ('invoice_no', 'nunique'),
                                                                               n_products = ('stock_code', 'nunique')).reset_index() )

df_aux['avg_unique_basket_size'] = df_aux['n_products'] / df_aux['n_purchase']
df_ref = pd.merge(df_ref, df_aux[['customer_id', 'avg_unique_basket_size']], on='customer_id', how='left')
df_ref.isna().sum()
# Out:
# customer_id                0
# gross_revenue             33
# recency_days              33
# qtde_invoices_x           33
# qtde_invoices_y           33
# qtde_items                33
# qtde_products             33
# avg_ticket                33
# frequency                 33
# qtde_returns               0
# avg_basket_size           33
# avg_unique_basket_size    33
# dtype: int64

# %%
aux = ( filtro.loc[:, ['customer_id', 'invoice_no', 'stock_code']].groupby('customer_id')
                                                                          .agg(n_purchase = ('invoice_no', 'nunique'),
                                                                               n_products = ('stock_code', 'nunique')).reset_index() )

aux['avg_unique_basket_size'] = aux['n_products'] / aux['n_purchase']
df3 = pd.merge(df3, aux[['customer_id', 'avg_unique_basket_size']], on='customer_id', how='left')
df3.isna().sum()
# Out:
# invoice_no                   0
# stock_code                   0
# quantity                     0
# invoice_date                 0
# unit_price                   0
# customer_id                  0
# country                      0
# year                         0
# month                        0
# month_sin                    0
# month_cos                    0
# gross_revenue                0
# returned                     0
# recency_days                 0
# n_invoice                    0
# qtde_items                   0
# qtde_products                0
# avg_ticket                   0
# frequency                    0
# n_returned                   0
# avg_basket_size              0
# avg_unique_basket_size    2411
# dtype: int64

# %%
df3['avg_unique_basket_size'] = df3['avg_unique_basket_size'].apply(lambda x: 0 if x == 'nan' or 'Nan' or 'NAN' or 'NaN' else x)

# %%
df3.isna().sum()
# Out:
# invoice_no                0
# stock_code                0
# quantity                  0
# invoice_date              0
# unit_price                0
# customer_id               0
# country                   0
# year                      0
# month                     0
# month_sin                 0
# month_cos                 0
# gross_revenue             0
# returned                  0
# recency_days              0
# n_invoice                 0
# qtde_items                0
# qtde_products             0
# avg_ticket                0
# frequency                 0
# n_returned                0
# avg_basket_size           0
# avg_unique_basket_size    0
# dtype: int64

# %% [markdown]
# # 5.0 Exploratory Data Analysis

# %%
df4 = df_ref.dropna()
df4.isna().sum()
# Out:
# customer_id               0
# gross_revenue             0
# recency_days              0
# qtde_invoices_x           0
# qtde_invoices_y           0
# qtde_items                0
# qtde_products             0
# avg_ticket                0
# frequency                 0
# qtde_returns              0
# avg_basket_size           0
# avg_unique_basket_size    0
# dtype: int64

# %%
df4.drop(columns = 'qtde_invoices_x', axis = 1, inplace = True)
df4.rename(columns = {'qtde_invoices_y': 'qtde_invoices'}, inplace = True)
df4.head()
# Out:
# /tmp/ipykernel_103797/2922505948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4.drop(columns = 'qtde_invoices_x', axis = 1, inplace = True)
# /tmp/ipykernel_103797/2922505948.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4.rename(columns = {'qtde_invoices_y': 'qtde_invoices'}, inplace = True)
#    customer_id  gross_revenue  recency_days  qtde_invoices  qtde_items  \
# 0      17850.0        5391.21         372.0           34.0      1733.0
# 1      13047.0        3237.54          31.0           10.0      1391.0
# 2      12583.0        7281.38           2.0           15.0      5060.0
# 3      13748.0         948.25          95.0            5.0       439.0
# 4      15100.0         876.00         333.0            3.0        80.0
#
#    qtde_products  avg_ticket  frequency  qtde_returns  avg_basket_size  \
# 0          297.0   18.152222  17.000000          40.0        50.970588
# 1          172.0   18.822907   0.029155          36.0       139.100000
# 2          247.0   29.479271   0.040323          51.0       337.333333
# 3           28.0   33.866071   0.017921           0.0        87.800000
# 4            3.0  292.000000   0.073171          22.0        26.666667
#
#    avg_unique_basket_size
# 0                0.617647
# 1               10.600000
# 2                7.666667
# 3                4.800000
# 4                0.333333

# %% [markdown]
# ## 5.1 Analise Univariada

# %%
#central tendency - mean, median
ct1 = pd.DataFrame(round(df4.apply(np.mean),2)).T
ct2 = pd.DataFrame(round(df4.apply(np.median),2)).T

#dispersion 
d1 = pd.DataFrame(round(df4.apply(np.std),2)).T
d2 = pd.DataFrame(round(df4.apply(np.min),2)).T
d3 = pd.DataFrame(round(df4.apply(np.max),2)).T
d4 = pd.DataFrame(round(df4.apply(lambda x: x.max() - x.min()),2)).T
d5 = pd.DataFrame(round(df4.apply(lambda x: x.std()/x.mean()),2)).T


#concatenate
m = pd.concat([d2 ,d3, d4, ct1, ct2, d1, d5]).T.reset_index()
m = m.drop([0])
m.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'CV'  ]
m
# Out:
#                 attributes   min        max      range     mean  median  \
# 1            gross_revenue  0.00  280206.02  280206.02  2053.79  674.45
# 2             recency_days  0.00     373.00     373.00    92.04   50.00
# 3            qtde_invoices  1.00     210.00     209.00     4.27    2.00
# 4               qtde_items  1.00  197491.00  197490.00  1194.21  379.00
# 5            qtde_products  1.00    7847.00    7846.00    91.71   41.00
# 6               avg_ticket  0.00   77183.60   77183.60    68.30   17.72
# 7                frequency  0.01      17.00      16.99     0.40    0.05
# 8             qtde_returns  0.00   80995.00   80995.00    63.13    0.00
# 9          avg_basket_size  1.00   74215.00   74214.00   256.31  161.75
# 10  avg_unique_basket_size  0.20     219.00     218.80    18.69   14.00
#
#         std     CV
# 1   8987.21   4.38
# 2    100.00   1.09
# 3      7.70   1.80
# 4   5055.02   4.23
# 5    228.77   2.49
# 6   1467.58  21.49
# 7      0.56   1.39
# 8   1689.78  26.77
# 9   1325.79   5.17
# 10    17.17   0.92

# %% [markdown]
# ### 5.1.1 Gross Revenue

# %%
plt.figure( figsize = (14, 4))
plt.subplot( 1, 2, 1 )
sns.boxplot(data = df4[df4['gross_revenue'] < 3000], x = 'gross_revenue' )

plt.subplot(1,2, 2)
sns.histplot (data = df4[df4['gross_revenue']< 3000], x = 'gross_revenue')
plt.show()

# %%
df4.sort_values('gross_revenue', ascending=False).head()
# Out:
#       customer_id  gross_revenue  recency_days  qtde_invoices  qtde_items  \
# 908       14646.0      280206.02           1.0           74.0    197491.0
# 450       18102.0      259657.30           0.0           60.0     64124.0
# 402       17450.0      194550.79           8.0           46.0     69993.0
# 2653      16446.0      168472.50           0.0            2.0     80997.0
# 67        14911.0      143825.06           1.0          201.0     80515.0
#
#       qtde_products    avg_ticket  frequency  qtde_returns  avg_basket_size  \
# 908          2080.0    134.714433   0.209040         772.0      2668.797297
# 450           431.0    602.453132   0.163043           2.0      1068.733333
# 402           337.0    577.302047   0.127778         964.0      1521.586957
# 2653            3.0  56157.500000   0.009709       80995.0     40498.500000
# 67           5677.0     25.334694   0.538874        3335.0       400.572139
#
#       avg_unique_basket_size
# 908                 9.472973
# 450                 2.500000
# 402                 2.695652
# 2653                1.500000
# 67                  8.890547

# %% [markdown]
# ### 5.1.2 Recency days

# %%
* Maior partes do clientes do banco de dados compraram até 75 dias
* 50 dia é a média segundo o gráfico do boxplot

# %%
plt.figure(figsize = (14,4))
plt.subplot(1, 2, 1)
sns.boxplot( data = df4,   x = 'recency_days')

plt.subplot(1 , 2, 2 )
sns.histplot( data = df4, x = 'recency_days')
plt.axvline(x=75, color='r', linestyle='--')
plt.show()

# %% [markdown]
# ### 5.1.3 Quantidade de Invoices

# %% [markdown]
# *

# %%
plt.figure(figsize = (14,4))
plt.subplot(1, 2, 1)
sns.boxplot( data = df4,   x = 'qtde_items')

plt.subplot(1 , 2, 2 )
sns.histplot( data = df4, x = 'qtde_items')
#plt.axvline(x=75, color='r', linestyle='--')
plt.show()

# %%
plt.figure(figsize = (14,4))
plt.subplot(1, 2, 1)
sns.boxplot( data = df4,   x = 'qtde_items')

plt.subplot(1 , 2, 2 )
sns.histplot( data = df4[df4['qtde_items'] < 3000], x = 'qtde_items')
plt.axvline(x=100, color='r', linestyle='--')
plt.show()

# %% [markdown]
# Boa partes das pessoas que compra no nosso site, já obtiveram por volta de 400 items

# %% [markdown]
# ### 4.1.4 Avg. Ticket

# %%
plt.figure(figsize = (14,4))
plt.subplot(1, 2, 1)
sns.boxplot( data = df4,   x = 'avg_ticket')

plt.subplot(1 , 2, 2 )
sns.histplot( data = df4[df4['avg_ticket'] < 500], x = 'avg_ticket')
plt.axvline(x=20, color='r', linestyle='--')
plt.show()

# %% [markdown]
# ### 5.2.1 Bivariate Analysis

# %% [markdown]
# ### 5.3 Estudo do Espaço

# %%
#selected dataset
cols_selected = ['customer_id', 'gross_revenue', 'recency_days', 'qtde_products', 'frequency', 'qtde_returns']
df43 = df4[cols_selected].drop(columns='customer_id', axis=1)

# %%
mm = pp.MinMaxScaler()

df43['gross_revenue']          = mm.fit_transform(df43[['gross_revenue']])
df43['recency_days']            = mm.fit_transform(df43[['recency_days']])
df43['qtde_products']          = mm.fit_transform(df43[['qtde_products']])
df43['frequency']              = mm.fit_transform(df43[['frequency']])
df43['qtde_returns']           = mm.fit_transform(df43[['qtde_returns']])

X = df43.copy()
X.head()

# %%
pca = dd.PCA(n_components = X.shape[1])

principal_components = pca.fit_transform(X)

#plot explained variables
features = range(pca.n_components_)

plt.bar(features, pca.explained_variance_ratio_, color='black')

#pca component
df_pca = pd.DataFrame(principal_components)

# %%
sns.scatterplot(x=0, y=1, data=df_pca);

# %% [markdown]
# ### 5.3.2 UMAP

# %%
reducer = umap.UMAP(random_state=42)
embedding = reducer.fit_transform(X)

#embedding
df_umap = pd.DataFrame()
df_umap['embedding_x'] = embedding[:, 0]
df_umap['embedding_y'] = embedding[:, 1]

#plot UMAP
sns.scatterplot(x='embedding_x', y='embedding_y', data=df_umap)

# %% [markdown]
# ### 5.3.3 UMAP

# %%
reducer = mn.TSNE(n_components=2, n_jobs=-1, random_state=42) 
embedding = reducer.fit_transform(X)

#embedding
df_tsne = pd.DataFrame()
df_tsne['embedding_x'] = embedding[:, 0]
df_tsne['embedding_y'] = embedding[:, 1]

#plot UMAP
sns.scatterplot(x='embedding_x', y='embedding_y', data=df_tsne)

# %% [markdown]
# ### 4.3.3 T-SNE

# %%
reducer = mn.TSNE(n_components=2, n_jobs=-1, random_state=42) 
embedding = reducer.fit_transform(X)

#embedding
df_tsne = pd.DataFrame()
df_tsne['embedding_x'] = embedding[:, 0]
df_tsne['embedding_y'] = embedding[:, 1]

#plot UMAP
sns.scatterplot(x='embedding_x', y='embedding_y', data=df_tsne)

# %% [markdown]
# ### 4.3.4 Tree-Based Embedding

# %%
X = df43.drop(columns=['gross_revenue'], axis=1)
y = df43['gross_revenue']

rf_model = en.RandomForestRegressor(n_estimators=100, random_state=42) #sao criadas 100 arvores 

rf_model.fit(X,y)

df_leaf = pd.DataFrame(rf_model.apply(X))

# %%
df_leaf.head()

# %%
#reducer dimensionality
reducer = umap.UMAP(random_state=42)
embedding = reducer.fit_transform(df_leaf)

#embedding
df_tree = pd.DataFrame()
df_tree['embedding_x'] = embedding[:, 0]
df_tree['embedding_y'] = embedding[:, 1]

#plot UMAP
sns.scatterplot(x='embedding_x', y='embedding_y', data=df_tree)

# %% [markdown]
# ## 5.2 Creating of hypotheses

# %% [markdown]
# Embora a validação de hipóteses seja feito em Analise exploratória de dados, realizada aqui para aumentar familiariadade com dados

# %% [markdown]
# ### H1 - O país sede de origem do site é o que mais vende!
#
# **TRUE**

# %%
aux = df4.loc[:,['country', 'quantity']].groupby('country').sum().sort_values('quantity', ascending = False)

# %%
aux = df4.loc[:,['country', 'quantity']].groupby('country').sum().sort_values('quantity', ascending = False)
sns.barplot(x = 'country', y = 'quantity', data = aux)

plt.xticks( rotation = 90)

plt.show()

# %%
df4[['customer_id', 'country']].drop_duplicates().groupby('country').count().sort_values('customer_id',ascending = False )
# Out:
#                       customer_id
# country
# United Kingdom               3950
# Germany                        95
# France                         87
# Spain                          31
# Belgium                        25
# Switzerland                    21
# Portugal                       19
# Italy                          15
# Finland                        12
# Austria                        11
# Norway                         10
# Australia                       9
# Denmark                         9
# Netherlands                     9
# Channel Islands                 9
# Japan                           8
# Sweden                          8
# Cyprus                          8
# Poland                          6
# Unspecified                     4
# USA                             4
# Canada                          4
# Israel                          4
# Greece                          4
# EIRE                            3
# United Arab Emirates            2
# Bahrain                         2
# Malta                           2
# Brazil                          1
# Lebanon                         1
# Iceland                         1
# Czech Republic                  1
# European Community              1
# Saudi Arabia                    1
# RSA                             1
# Lithuania                       1
# Singapore                       1

# %%
# Em porcentagem
df4['country'].value_counts(normalize = True).head()
# Out:
# country
# United Kingdom    0.889509
# Germany           0.023339
# France            0.020871
# EIRE              0.018398
# Spain             0.006226
# Name: proportion, dtype: float64

# %% [markdown]
# ### H2 - Qual produto que mais vende

# %%
aux = df4.loc[df4['quantity']>= 0]
aux = aux.loc[:, ['stock_code', 'quantity']].groupby('stock_code').sum().sort_values('quantity', ascending = False)
aux
# Out:
#             quantity
# stock_code
# 23843          80995
# 23166          77916
# 84077          54415
# 22197          49183
# 85099B         46181
# ...              ...
# 90024D             1
# 90025F             1
# 90011A             1
# 20667              1
# 90165B             1
#
# [3665 rows x 1 columns]

# %% [markdown]
# | Produto     | Description|
# |--------------|-----------|
# |23843	|PAPER CRAFT , LITTLE BIRDIE|
# |23166	|MEDIUM CERAMIC TOP STORAGE JAR|
# |84077	|WORLD WAR 2 GLIDERS ASSTD DESIGNS|
# |22197	|SMALL POPCORN HOLDER|
# |85099B	|JUMBO BAG RED RETROSPOT|

# %% [markdown]
# ### H3 - De qual país é o cliente que mais compra
#
# **o Cliente que mais compra é da United Kingdom**

# %%
df4.head()
# Out:
#   invoice_no stock_code  quantity invoice_date  unit_price  customer_id  \
# 0     536365     85123A         6   2016-11-29        2.55      17850.0
# 1     536365      71053         6   2016-11-29        3.39      17850.0
# 2     536365     84406B         8   2016-11-29        2.75      17850.0
# 3     536365     84029G         6   2016-11-29        3.39      17850.0
# 4     536365     84029E         6   2016-11-29        3.39      17850.0
#
#           country  year  month  month_sin  month_cos  gross_revenue  returned  \
# 0  United Kingdom  2016     11       -0.5   0.866025          15.30         0
# 1  United Kingdom  2016     11       -0.5   0.866025          20.34         0
# 2  United Kingdom  2016     11       -0.5   0.866025          22.00         0
# 3  United Kingdom  2016     11       -0.5   0.866025          20.34         0
# 4  United Kingdom  2016     11       -0.5   0.866025          20.34         0
#
#    recency_days  n_invoice  qtde_items  qtde_products  avg_ticket
# 0           373         35        1693            312   18.152222
# 1           373         35        1693            312   18.152222
# 2           373         35        1693            312   18.152222
# 3           373         35        1693            312   18.152222
# 4           373         35        1693            312   18.152222

# %%
aux = df4.loc[:,['country', 'customer_id', 'quantity']].groupby(['country', 'customer_id']).count().sort_values('quantity', ascending = False)
aux
# Out:
#                             quantity
# country        customer_id
# United Kingdom 17841.0          7983
# EIRE           14911.0          5903
# United Kingdom 14096.0          5128
#                12748.0          4642
#                14606.0          2782
# ...                              ...
#                15510.0             1
#                18174.0             1
#                15668.0             1
#                14424.0             1
#                15657.0             1
#
# [4380 rows x 1 columns]

# %% [markdown]
# ### H4 - Qual o periodo do ano que mais vende ?
#
# Do mễs de outubro ao dezembro

# %%
df4.head()
# Out:
#   invoice_no stock_code  quantity invoice_date  unit_price  customer_id  \
# 0     536365     85123A         6   2016-11-29        2.55      17850.0
# 1     536365      71053         6   2016-11-29        3.39      17850.0
# 2     536365     84406B         8   2016-11-29        2.75      17850.0
# 3     536365     84029G         6   2016-11-29        3.39      17850.0
# 4     536365     84029E         6   2016-11-29        3.39      17850.0
#
#           country  year  month  month_sin  month_cos  gross_revenue  returned  \
# 0  United Kingdom  2016     11       -0.5   0.866025          15.30         0
# 1  United Kingdom  2016     11       -0.5   0.866025          20.34         0
# 2  United Kingdom  2016     11       -0.5   0.866025          22.00         0
# 3  United Kingdom  2016     11       -0.5   0.866025          20.34         0
# 4  United Kingdom  2016     11       -0.5   0.866025          20.34         0
#
#    recency_days  n_invoice  qtde_items  qtde_products  avg_ticket
# 0           373         35        1693            312   18.152222
# 1           373         35        1693            312   18.152222
# 2           373         35        1693            312   18.152222
# 3           373         35        1693            312   18.152222
# 4           373         35        1693            312   18.152222

# %%
# Converta a coluna 'Timestamp' para o formato datetime
df4['invoice_date'] = pd.to_datetime(df4['invoice_date'])

# Crie um filtro para selecionar os valores antes de 2017
filtro = df4[df4['invoice_date'].dt.year < 2017]
filtro
# Out:
#       invoice_no stock_code  quantity invoice_date  unit_price  customer_id  \
# 0         536365     85123A         6   2016-11-29        2.55      17850.0
# 1         536365      71053         6   2016-11-29        3.39      17850.0
# 2         536365     84406B         8   2016-11-29        2.75      17850.0
# 3         536365     84029G         6   2016-11-29        3.39      17850.0
# 4         536365     84029E         6   2016-11-29        3.39      17850.0
# ...          ...        ...       ...          ...         ...          ...
# 26845     539988      84380         1   2016-12-21        1.25      18116.0
# 26846     539988     84849D         1   2016-12-21        1.69      18116.0
# 26847     539988     84849B         1   2016-12-21        1.69      18116.0
# 26848     539988      22854         2   2016-12-21        4.95      18116.0
# 26849     539988     47559B         2   2016-12-21        1.25      18116.0
#
#               country  year  month     month_sin  month_cos  gross_revenue  \
# 0      United Kingdom  2016     11 -5.000000e-01   0.866025          15.30
# 1      United Kingdom  2016     11 -5.000000e-01   0.866025          20.34
# 2      United Kingdom  2016     11 -5.000000e-01   0.866025          22.00
# 3      United Kingdom  2016     11 -5.000000e-01   0.866025          20.34
# 4      United Kingdom  2016     11 -5.000000e-01   0.866025          20.34
# ...               ...   ...    ...           ...        ...            ...
# 26845  United Kingdom  2016     12 -2.449294e-16   1.000000           1.25
# 26846  United Kingdom  2016     12 -2.449294e-16   1.000000           1.69
# 26847  United Kingdom  2016     12 -2.449294e-16   1.000000           1.69
# 26848  United Kingdom  2016     12 -2.449294e-16   1.000000           9.90
# 26849  United Kingdom  2016     12 -2.449294e-16   1.000000           2.50
#
#        returned  recency_days  n_invoice  qtde_items  qtde_products  \
# 0             0           373         35        1693            312
# 1             0           373         35        1693            312
# 2             0           373         35        1693            312
# 3             0           373         35        1693            312
# 4             0           373         35        1693            312
# ...         ...           ...        ...         ...            ...
# 26845         0           351          8         848            378
# 26846         0           351          8         848            378
# 26847         0           351          8         848            378
# 26848         0           351          8         848            378
# 26849         0           351          8         848            378
#
#        avg_ticket
# 0       18.152222
# 1       18.152222
# 2       18.152222
# 3       18.152222
# 4       18.152222
# ...           ...
# 26845    3.751402
# 26846    3.751402
# 26847    3.751402
# 26848    3.751402
# 26849    3.751402
#
# [26850 rows x 18 columns]

# %%
# 2016
aux =  filtro.loc[:,['invoice_date', 'quantity']].groupby('invoice_date').sum().sort_values('quantity', ascending = False)
aux.head()
# Out:
#               quantity
# invoice_date
# 2016-12-14       29482
# 2016-11-29       24032
# 2016-12-06       21275
# 2016-11-30       20855
# 2016-12-05       19351

# %%
# 2017


# Converta a coluna 'Timestamp' para o formato datetime
df4['invoice_date'] = pd.to_datetime(df4['invoice_date'])

# Crie um filtro para selecionar os valores antes de 2017
filtro = df4[df4['invoice_date'].dt.year > 2016]
filtro
aux =  filtro.loc[:,['invoice_date', 'quantity']].groupby('invoice_date').sum().sort_values('quantity', ascending = False)
aux.head()
# Out:
#               quantity
# invoice_date
# 2017-10-03       45741
# 2017-09-18       42626
# 2017-12-05       40994
# 2017-10-18       40780
# 2017-12-03       38305

# %% [markdown]
# ### H5 - Qual o periodo do ano que menos vende?
# Fevereiro e Março

# %%
# 2016


# Converta a coluna 'Timestamp' para o formato datetime
df4['invoice_date'] = pd.to_datetime(df4['invoice_date'])

# Crie um filtro para selecionar os valores antes de 2017
filtro = df4[df4['invoice_date'].dt.year > 2016]
filtro
aux =  filtro.loc[:,['invoice_date', 'quantity']].groupby('invoice_date').sum().sort_values('quantity', ascending = True)
aux.head()
# Out:
#               quantity
# invoice_date
# 2017-02-04        2048
# 2017-02-11        2715
# 2017-03-11        2741
# 2017-07-01        3106
# 2017-08-12        3135

# %%
# 2017


# Converta a coluna 'Timestamp' para o formato datetime
df4['invoice_date'] = pd.to_datetime(df4['invoice_date'])

# Crie um filtro para selecionar os valores antes de 2017
filtro = df4[df4['invoice_date'].dt.year > 2016]
filtro
aux =  filtro.loc[:,['invoice_date', 'quantity']].groupby('invoice_date').sum().sort_values('quantity', ascending = True)
aux.head()
# Out:
#               quantity
# invoice_date
# 2017-02-04        2048
# 2017-02-11        2715
# 2017-03-11        2741
# 2017-07-01        3106
# 2017-08-12        3135

# %% [markdown]
# # 6.0 Data Preparation

# %% [markdown]
# # 7.0 Hypermarameter Fine-Tunning

# %%
X = df_tree.copy()

# %% [markdown]
# X.head()

# %% [markdown]
# clusters = np.arange(2,25,1)

# %% [markdown]
# ## 7.1 K-Means

# %%
kmeans_list = []

for k in clusters:
    #model definition
    kmeans_model = c.KMeans(n_clusters=k, n_init = 100, random_state=42)

    #model training
    kmeans_model.fit(X)

    #model predict
    labels = kmeans_model.predict(X)

    #model performance 
    sil = m.silhouette_score(X, labels, metric='euclidean')
    kmeans_list.append(sil)

# %%
plt.plot(clusters, kmeans_list, linestyle='--', marker='o', color='b')
plt.xlabel('Values of K')
plt.ylabel('Silhouete Score')
plt.title('Silhouete Score vs K')

# %% [markdown]
# ## 7.2 GMM

# %%
gmm_list = []

for k in clusters:
    #model definition
    gmm_model = mx.GaussianMixture(n_components=k, random_state=42)  #define quantas guassianas eu quero


    #model training
    gmm_model.fit(X)

    #model predict
    labels = gmm_model.predict(X)

    #model performance 
    sil = m.silhouette_score(X, labels, metric='euclidean')
    gmm_list.append(sil)

# %%
plt.plot(clusters, gmm_list, linestyle='--', marker='o', color='b')
plt.xlabel('Values of K')
plt.ylabel('Silhouete Score')
plt.title('Silhouete Score vs K')

# %% [markdown]
# ## 7.3 Hierarchical Clustering

# %%
#model deinition and training
hc_model = hc.linkage(X,'ward')

# %%
#hc.dendrogram( hc_model, leaf_rotation=90, leaf_font_size=8)
#plt.plot()

# %%
hc_list = []
for k in clusters:
    #model definition and training
    hc_model = hc.linkage(X,'ward')
    
    #model predict
    labels = hc.fcluster(hc_model, k, criterion='maxclust')
    
    #metrics
    sil = m.silhouette_score(X, labels, metric='euclidean')
    hc_list.append(sil)

# %%
plt.plot(clusters, hc_list, linestyle='--', marker='o', color='b')

# %% [markdown]
# ## 7.5 Results

# %%
df_results = pd.DataFrame({'KMeans': kmeans_list, 'GMM': gmm_list, 'HC': hc_list}).T
df_results.columns = clusters
df_results.style.highlight_max(color='lightgreen', axis=1)

# %%
8.0 Model Training

# %%
8.1 k-Means

# %%
#model definition
k = 7
kmeans = c.KMeans(init='random', n_clusters=k, n_init=10, max_iter=300, random_state=42)

#model trainning
kmeans.fit(X)

#clustering
labels = kmeans.labels_
#labels = kmeans.fit_predict(X) #tirar o fit de cima

# %%
8.2 Cluster Validation

# %%
#SS
print('SS value: {}'.format(m.silhouette_score(X, labels, metric='euclidean')))

# %%
9.0 Cluster Analysis

# %%
df9 = X.copy()
df9['cluster'] = labels
df9.head()

# %%
9.1 Visualization Inspection

# %%
plt.figure(figsize=(14, 8))
sns.scatterplot(x='embedding_x', y='embedding_y', hue='cluster', data=df9, palette='deep');

# %%
9.2 Cluster Profile

# %%
df4.head()

# %%
df92 = df4[cols_selected].copy()
df92['cluster'] = labels
df92.head()

# %%
#Number customer
df_cluster = df92.groupby('cluster').customer_id.count().reset_index()
df_cluster['perc_customer'] = 100*(df_cluster['customer_id'] / df_cluster['customer_id'].sum())

#Avg Gross Revenue
df_avg_gross_revenue = df92.groupby('cluster').gross_revenue.mean().reset_index()
df_cluster = pd.merge(df_cluster, df_avg_gross_revenue, how='inner', on='cluster')

#Avg Recency Days
df_avg_recency_days = df92.groupby('cluster').recency_days.mean().reset_index()
df_cluster = pd.merge(df_cluster, df_avg_recency_days, how='inner', on='cluster')

#Avg invoice_no
df_qtde_products = df92.groupby('cluster').qtde_products.mean().reset_index()
df_cluster = pd.merge(df_cluster, df_qtde_products, how='inner', on='cluster')

#Frequency
df_frequency = df92.groupby('cluster').frequency.mean().reset_index()
df_cluster = pd.merge(df_cluster, df_frequency, how='inner', on='cluster')

#Returns
df_qtde_returns = df92.groupby('cluster').qtde_returns.mean().reset_index()
df_cluster = pd.merge(df_cluster, df_qtde_returns, how='inner', on='cluster')


df_cluster.sort_values('gross_revenue', ascending=False)

# %%
10.0 EDA

# %%
df10 = df92

# %%
H1. Os clientes do cluster insiders possuem um volume de compra de produtos acima de 10% do totatl de compras

verdadeiro: O cluster insider possui um volume de compra de 54%

# %%
#df10[df10['cluster'] ==1].groupby('cluster').qtde_products.sum().reset_index()

#sum the quantity of products of insiders
df_sales_insiders = df10[df10['cluster'] == 6].qtde_products.sum() #substituir depois o cluster correspondente ao insiders
df_sales_total = df10.qtde_products.sum()

#percentage of sales of insiders by the total product sales
print('% Sales Insiders: {:.2f}'.format(100*df_sales_insiders/df_sales_total))

# %%
H2. Os clientes do cluster insiders possuem um volume de faturamento de compras acima de 10% do total de compras

verdadeiro: O cluster insider possui um volume de gmv de 52%

# %%
#sum the gmv of insiders
df_gmv_insiders = df10[df10['cluster'] == 6].gross_revenue.sum() #substituir depois o cluster correspondente ao insiders
df_gmv_total = df10.gross_revenue.sum()

#percentage of sales of insiders by the tot/al product sales
print('% Sales Insiders: {:.2f}'.format(100*df_gmv_insiders/df_gmv_total))

# %%
H3. Os clientes do cluster insiders tem numero de devolução médio abaixo do media da base total de clientes

Falso: O cluster insiders tem a média de devolução acima da média geral

# %%
df_avg_return_insiders = df10[df10['cluster'] == 6].qtde_returns.mean()
df_avg_return_total = df10.qtde_returns.mean()

print('Avg Return insiders: {} vs Avg Returns total: {}'.format(np.round(df_avg_return_insiders, 0),
                                                               np.round(df_avg_return_total, 0)))

# %%
H4. A mediana do faturamento pelos clientes do cluster insider é 10% do que a mediana do faturamento geral

verdadeiro: A mediana do faturamento é 279% acima da mediana

# %%
#mediana de gmv do insiders
df_median_gmv_insiders = df10[df10['cluster'] == 6].gross_revenue.median()

#mediana de gmv do total
df_median_gmv_total = df10.gross_revenue.median()

gmv_diff = (df_median_gmv_insiders - df_median_gmv_total) / df_median_gmv_total
print('Median Diff: {:.2f}%'.format(100*gmv_diff))

# %%
H5. O GMV dos clientes insiders está concentradas no 3 quartil

Falso: O faturamento do cluster insiders esta concentrada no quartil 1

# %%
np.percentile(df10[df10['cluster'] == 3].gross_revenue, q=0.1)

# %%
np.percentile(df10[df10['cluster'] == 3].gross_revenue, q=0.9)

# %%
df_aux = (df10[(df10['cluster'] == 3) & 
               (df10['gross_revenue'] < 10000)]
               .gross_revenue)
sns.boxplot(x=df_aux)

# %%
df_aux = (df10[(df10['cluster'] == 3) &
               (df10['gross_revenue'] < 10000)]
               .gross_revenue)
sns.violinplot(x=df_aux)
